# %%
notebook_iteration = "i10a"

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
# !nvidia-smi -L

#avoid running into GPU OOM errors because TF greedily allocates all GPU memory
# for the first training run and doesn't release it, so no more memory is available for 
# the second.
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-058a48ed-bc51-51bd-a0fc-4b2f626c8efc)
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Set configs

# %%
from pathlib import Path

#data_dir = Path("/content/drive/MyDrive/OTH/space-eye/dataset/flattened_cropped")
base_dir = Path("/content/drive/MyDrive/OTH/space-eye")
data_dir = Path("/content/drive/MyDrive/OTH/space-eye/dataset/jpg600")
model_dir =  base_dir / "models" / notebook_iteration
log_dir = base_dir / "logs" / notebook_iteration
tuner_dir = base_dir / "tuner" / notebook_iteration
img_height = 400
img_width = 400
batch_size = 16
num_splits = 5 # for k-fold crossvalidation

# %% [markdown]
# ## Copy data to local runtime

# %%
# !mkdir /dataset
# !cp -r $data_dir/* /dataset
data_dir = Path("/dataset")
# Out:
# mkdir: cannot create directory ‘/dataset’: File exists

# %%
nonships_count = len(list(data_dir.glob('nonships/*')))
ships_count = len(list(data_dir.glob('ships/*')))

ships_count, nonships_count
# Out:
# (871, 880)

# %% [markdown]
# ## Load Data

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import pandas as pd
from pathlib import Path
import os

# load metadata
nonships_meta = pd.read_csv(Path("/content/drive/MyDrive/OTH/space-eye/dataset/nonshipsAIS_2017_Zone17.csv"), index_col=None)
ships_meta = pd.read_csv(Path("/content/drive/MyDrive/OTH/space-eye/dataset/shipsAIS_2017_Zone17.csv"), index_col=None)

# remove duplicate entries from csv data
nonships_meta = nonships_meta.drop_duplicates(subset="newindex")
ships_meta = ships_meta.drop_duplicates(subset="newindex")

# find image files
data = []
classifiers = os.listdir(data_dir)
for classifier in classifiers:
  classifier_dir = os.path.join(data_dir, classifier)
  for item in sorted(os.listdir(classifier_dir)):
    filename = os.path.join(classifier, item)
    number = Path(filename).stem.split("_")[-1]
    data.append([str(filename), str(classifier), int(number)])

image_data = pd.DataFrame(data, columns=['filename', 'class', 'number'])

#merge data
ships_meta["class"] = "ships"
ships_meta.rename(columns={"newindex" : "number"}, inplace=True)
nonships_meta["class"] = "nonships"
nonships_meta.rename(columns={"newindex" : "number"}, inplace=True)

df_data = image_data
df_data = pd.merge(df_data, ships_meta, how='left', on=["number", "class"])
df_data = pd.merge(df_data, nonships_meta, how='left', on=["number", "class"])

df_data
# Out:
#                             filename  ...                                         envelope_y
# 0            ships/ships_image_0.jpg  ...                                                NaN
# 1            ships/ships_image_1.jpg  ...                                                NaN
# 2           ships/ships_image_10.jpg  ...                                                NaN
# 3          ships/ships_image_100.jpg  ...                                                NaN
# 4          ships/ships_image_101.jpg  ...                                                NaN
# ...                              ...  ...                                                ...
# 1746  nonships/nonships_image_95.jpg  ...  POLYGON ((-79.98891429114776 26.34658744768258...
# 1747  nonships/nonships_image_96.jpg  ...  POLYGON ((-79.96215555981016 26.47006574369414...
# 1748  nonships/nonships_image_97.jpg  ...  POLYGON ((-79.96756047140948 26.68008743099022...
# 1749  nonships/nonships_image_98.jpg  ...  POLYGON ((-79.97636915029581 26.68351465628567...
# 1750  nonships/nonships_image_99.jpg  ...  POLYGON ((-80.03769046501085 25.7212426966049,...
#
# [1751 rows x 25 columns]

# %% [markdown]
# ### Display some loaded images

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

viz_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)

plt.figure(figsize=(15, 15))
for images, labels in viz_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
# Out:
# Found 1751 files belonging to 2 classes.

# %% [markdown]
# ## Set up and visualize Data Augmentation

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
    ]
)

plt.figure(figsize=(10, 10))
for images, _ in viz_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ## Define Model

# %%
from tensorflow import keras
import keras.backend as K

# def recall_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
#     recall = true_positives / (possible_positives + K.epsilon())
#     return recall

# def precision_m(y_true, y_pred):
#     true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
#     predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
#     precision = true_positives / (predicted_positives + K.epsilon())
#     return precision

# def f1_m(y_true, y_pred):
#     precision = precision_m(y_true, y_pred)
#     recall = recall_m(y_true, y_pred)
#     return 2*((precision*recall)/(precision+recall+K.epsilon()))

def build_model_tuner(hp):
  learning_rate = hp.Float('learning_rate', 1e-04, 0.01, sampling='log')
  model = build_model()
  #lr_schedule1 = optimizers.schedules.ExponentialDecay(initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9)
  
  model.compile(
      optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
      loss='binary_crossentropy',
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  return model

def build_model():
  base_model = keras.applications.InceptionResNetV2(
      weights="imagenet",  # Load weights pre-trained on ImageNet.
      input_shape=(img_width, img_height, 3),
      include_top=False,
  )  # Do not include the ImageNet classifier at the top.

  # Freeze the base_model
  base_model.trainable = False

  # Create new model on top
  inputs = keras.Input(shape=(img_width, img_height, 3))
  x = inputs
  x = data_augmentation(inputs)  # Apply random data augmentation

  # Pre-trained Xception weights requires that input be scaled
  # from (0, 255) to a range of (-1., +1.), the rescaling layer
  # outputs: `(inputs * scale) + offset`
  scale_layer = keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
  x = scale_layer(x)


  # The base model contains batchnorm layers. We want to keep them in inference mode
  # when we unfreeze the base model for fine-tuning, so we make sure that the
  # base_model is running in inference mode here.
  x = base_model(x, training=False)
  x = keras.layers.Flatten()(x)
  x = keras.layers.Dense(512, activation="relu")(x)
  x = keras.layers.Dropout(0.5)(x)
  outputs = keras.layers.Dense(1, activation='sigmoid')(x)
  model = keras.Model(inputs, outputs)
  model.summary()
  
  return model

from tensorflow.keras import layers

def make_model(input_shape, num_classes):
  inputs = keras.Input(shape=input_shape)
  # Image augmentation block
  x = data_augmentation(inputs)
  x = inputs

  # Entry block
  x = layers.Rescaling(1.0 / 255)(x)
  x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  x = layers.Conv2D(64, 3, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  previous_block_activation = x  # Set aside residual

  for size in [128, 256, 512, 728]:
      x = layers.Activation("relu")(x)
      x = layers.SeparableConv2D(size, 3, padding="same")(x)
      x = layers.BatchNormalization()(x)

      x = layers.Activation("relu")(x)
      x = layers.SeparableConv2D(size, 3, padding="same")(x)
      x = layers.BatchNormalization()(x)

      x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

      # Project residual
      residual = layers.Conv2D(size, 1, strides=2, padding="same")(
          previous_block_activation
      )
      x = layers.add([x, residual])  # Add back residual
      previous_block_activation = x  # Set aside next residual

  x = layers.SeparableConv2D(1024, 3, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  x = layers.GlobalAveragePooling2D()(x)
  if num_classes == 2:
      activation = "sigmoid"
      units = 1
  else:
      activation = "softmax"
      units = num_classes

  x = layers.Dropout(0.5)(x)
  outputs = layers.Dense(units, activation=activation)(x)
  model = keras.Model(inputs, outputs)
  model.summary()
  return model

# %% [markdown]
# ## Train

# %%
# # displays tensorboard within the notebook
# %load_ext tensorboard
# %tensorboard --logdir $log_dir

# %%
import tensorflow as tf
from tensorflow.keras import metrics, optimizers
from sklearn.model_selection import KFold
from sklearn.metrics import roc_curve, roc_auc_score, auc, f1_score
import numpy as np
import time

tensorboard_dir = log_dir / "tensorboard" / time.strftime('%d_%m_%y-%H_%M')

#variables that hold our test results across runs
y_preds = []
y_tests = []
tprs = []
aucs = []
f1s = []
mean_fpr = np.linspace(0, 1, 100)

#set up dataset
full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)

for fold in range(num_splits):
  print("FOLD " + str(fold))
  
  #setup k-fold crossvalidations
  test_ds = full_ds.shard(num_splits, index=fold)
 
  fold_ds = full_ds.take(0)
  for i in range(num_splits):
    if i!=fold:
      fold_ds = fold_ds.concatenate(full_ds.shard(num_splits, index=i))
  
  fold_ds = fold_ds.shuffle(1000)
  
  num_in_fold = np.ceil((ships_count+nonships_count)*(1-1/num_splits)/batch_size)
  num_train = int(num_in_fold*0.8)
  num_val = num_in_fold - num_train
  
  train_ds = fold_ds.take(num_train)
  val_ds = fold_ds.skip(num_train).take(num_val)
  
  #improves performance
  AUTOTUNE = tf.data.AUTOTUNE
  train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
  
  # #Freeze the base model and only train the extra layer
  model = build_model()
  #model = make_model(input_shape=(img_width, img_height) + (3,), num_classes=2)

  lr_schedule1 = optimizers.schedules.ExponentialDecay(initial_learning_rate=0.01, decay_steps=25, decay_rate=0.8)
  
  model.compile(
      optimizer=optimizers.Adam(learning_rate=lr_schedule1),
      loss='binary_crossentropy',
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  tensorboard1_cb = tf.keras.callbacks.TensorBoard(tensorboard_dir / str(fold) / "a")
  checkpoint1_cb = tf.keras.callbacks.ModelCheckpoint(model_dir / str(fold) / "a" / "checkpoint_network.h5", monitor='val_loss', save_best_only=True)
  early_stopping1_cb = tf.keras.callbacks.EarlyStopping(patience=5, verbose=1, monitor='val_loss', restore_best_weights=True)
  callbacks1 = [checkpoint1_cb, tensorboard1_cb, early_stopping1_cb]
  model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=callbacks1)

  # Unfreeze the base_model and finetune whole model with low learning rate
  model.trainable = True
  model.summary()

  lr_schedule2 = optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-4, decay_steps=100, decay_rate=0.9)

  model.compile(
      optimizer=keras.optimizers.Adam(learning_rate=lr_schedule2),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  tensorboard2_cb = tf.keras.callbacks.TensorBoard(tensorboard_dir / str(fold) / "b")
  checkpoint2_cb = tf.keras.callbacks.ModelCheckpoint(model_dir / str(fold) / "b" / "checkpoint_network.h5", monitor='val_loss', save_best_only=True)
  early_stopping2_cb = tf.keras.callbacks.EarlyStopping(patience=10, verbose=1, monitor='val_loss', restore_best_weights=True)
  callbacks2 = [checkpoint2_cb, tensorboard2_cb, early_stopping2_cb]

  model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=callbacks2)

  model.save(model_dir / str(fold) / "final_network.h5")
  
  # extract data from sharded test dataset again (this is a pain)
  # otherwise, the labels were mismatched with the images for some reason
  x_test, y_test = [], []
  for images, labels in test_ds.unbatch():
    x_test.append(images.numpy())
    y_test.append(labels.numpy())
  x_test = np.array(x_test)
  y_test = np.array(y_test)

  # test predictions and calculate test metrics
  y_pred = model.predict(x_test).ravel().round().astype(int)
  y_preds.append(y_pred)
  y_tests.append(y_test)

  fpr, tpr, thresholds = roc_curve(y_test, y_pred)
  interp_tpr = np.interp(mean_fpr, fpr, tpr)
  interp_tpr[0] = 0.0
  tprs.append(interp_tpr)
  aucs.append(roc_auc_score(y_test, y_pred))
  f1s.append(f1_score(y_test, y_pred, average="binary"))

  print(f"fold {fold} f1: {f1_score(y_test, y_pred, average='binary')}")

  tf.keras.backend.clear_session()
# Out:
# Found 1751 files belonging to 2 classes.
# FOLD 0
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
#
#  dense (Dense)               (None, 512)               95158784
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 149,496,033
# Trainable params: 95,159,297
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 98s 824ms/step - loss: 103.9643 - binary_accuracy: 0.7455 - precision: 0.7421 - recall: 0.7298 - val_loss: 16.6219 - val_binary_accuracy: 0.8264 - val_precision: 0.8815 - val_recall: 0.7778
# Epoch 2/30
# 70/70 [==============================] - 31s 445ms/step - loss: 12.3760 - binary_accuracy: 0.8018 - precision: 0.7960 - recall: 0.7960 - val_loss: 4.0973 - val_binary_accuracy: 0.8194 - val_precision: 0.8531 - val_recall: 0.7974
# Epoch 3/30
# 70/70 [==============================] - 26s 373ms/step - loss: 3.7875 - binary_accuracy: 0.8170 - precision: 0.8133 - recall: 0.8088 - val_loss: 2.0893 - val_binary_accuracy: 0.8264 - val_precision: 0.8652 - val_recall: 0.7974
# Epoch 4/30
# 70/70 [==============================] - 26s 369ms/step - loss: 1.8007 - binary_accuracy: 0.8259 - precision: 0.8202 - recall: 0.8217 - val_loss: 1.3046 - val_binary_accuracy: 0.8403 - val_precision: 0.8408 - val_recall: 0.8627
# Epoch 5/30
# 70/70 [==============================] - 26s 376ms/step - loss: 1.4850 - binary_accuracy: 0.8205 - precision: 0.8147 - recall: 0.8162 - val_loss: 1.0317 - val_binary_accuracy: 0.8264 - val_precision: 0.8456 - val_recall: 0.8235
# Epoch 6/30
# 70/70 [==============================] - 25s 366ms/step - loss: 1.1947 - binary_accuracy: 0.8313 - precision: 0.8330 - recall: 0.8162 - val_loss: 0.9493 - val_binary_accuracy: 0.8472 - val_precision: 0.8562 - val_recall: 0.8562
# Epoch 7/30
# 70/70 [==============================] - 25s 360ms/step - loss: 1.3245 - binary_accuracy: 0.8321 - precision: 0.8190 - recall: 0.8401 - val_loss: 0.8678 - val_binary_accuracy: 0.8403 - val_precision: 0.8905 - val_recall: 0.7974
# Epoch 8/30
# 70/70 [==============================] - 25s 355ms/step - loss: 0.9548 - binary_accuracy: 0.8321 - precision: 0.8423 - recall: 0.8051 - val_loss: 0.8358 - val_binary_accuracy: 0.8576 - val_precision: 0.8836 - val_recall: 0.8431
# Epoch 9/30
# 70/70 [==============================] - 16s 236ms/step - loss: 0.9678 - binary_accuracy: 0.8420 - precision: 0.8456 - recall: 0.8254 - val_loss: 0.8491 - val_binary_accuracy: 0.8472 - val_precision: 0.8811 - val_recall: 0.8235
# Epoch 10/30
# 70/70 [==============================] - 30s 437ms/step - loss: 0.9667 - binary_accuracy: 0.8295 - precision: 0.8239 - recall: 0.8254 - val_loss: 0.8329 - val_binary_accuracy: 0.8264 - val_precision: 0.8759 - val_recall: 0.7843
# Epoch 11/30
# 70/70 [==============================] - 34s 483ms/step - loss: 0.7773 - binary_accuracy: 0.8411 - precision: 0.8427 - recall: 0.8272 - val_loss: 0.8288 - val_binary_accuracy: 0.8472 - val_precision: 0.8811 - val_recall: 0.8235
# Epoch 12/30
# 70/70 [==============================] - 26s 378ms/step - loss: 0.7999 - binary_accuracy: 0.8429 - precision: 0.8498 - recall: 0.8217 - val_loss: 0.8207 - val_binary_accuracy: 0.8438 - val_precision: 0.8803 - val_recall: 0.8170
# Epoch 13/30
# 70/70 [==============================] - 18s 262ms/step - loss: 0.8684 - binary_accuracy: 0.8241 - precision: 0.8305 - recall: 0.8015 - val_loss: 0.8219 - val_binary_accuracy: 0.8438 - val_precision: 0.8803 - val_recall: 0.8170
# Epoch 14/30
# 70/70 [==============================] - 16s 234ms/step - loss: 0.8708 - binary_accuracy: 0.8438 - precision: 0.8514 - recall: 0.8217 - val_loss: 0.8213 - val_binary_accuracy: 0.8472 - val_precision: 0.8811 - val_recall: 0.8235
# Epoch 15/30
# 70/70 [==============================] - 16s 231ms/step - loss: 0.8665 - binary_accuracy: 0.8339 - precision: 0.8429 - recall: 0.8088 - val_loss: 0.8213 - val_binary_accuracy: 0.8542 - val_precision: 0.8828 - val_recall: 0.8366
# Epoch 16/30
# 70/70 [==============================] - 16s 227ms/step - loss: 0.9825 - binary_accuracy: 0.8348 - precision: 0.8406 - recall: 0.8143 - val_loss: 0.8208 - val_binary_accuracy: 0.8542 - val_precision: 0.8828 - val_recall: 0.8366
# Epoch 17/30
# 70/70 [==============================] - ETA: 0s - loss: 1.1372 - binary_accuracy: 0.8464 - precision: 0.8591 - recall: 0.8180Restoring model weights from the end of the best epoch: 12.
# 70/70 [==============================] - 17s 246ms/step - loss: 1.1372 - binary_accuracy: 0.8464 - precision: 0.8591 - recall: 0.8180 - val_loss: 0.8207 - val_binary_accuracy: 0.8542 - val_precision: 0.8828 - val_recall: 0.8366
# Epoch 00017: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
#
#  dense (Dense)               (None, 512)               95158784
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 149,496,033
# Trainable params: 149,435,489
# Non-trainable params: 60,544
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 88s 906ms/step - loss: 0.5866 - binary_accuracy: 0.7312 - precision_1: 0.7288 - recall_1: 0.7114 - val_loss: 0.4356 - val_binary_accuracy: 0.8194 - val_precision_1: 0.8389 - val_recall_1: 0.8170
# Epoch 2/30
# 70/70 [==============================] - 60s 856ms/step - loss: 0.3478 - binary_accuracy: 0.8598 - precision_1: 0.8862 - recall_1: 0.8162 - val_loss: 0.3958 - val_binary_accuracy: 0.8576 - val_precision_1: 0.8784 - val_recall_1: 0.8497
# Epoch 3/30
# 70/70 [==============================] - 67s 957ms/step - loss: 0.3113 - binary_accuracy: 0.8777 - precision_1: 0.8847 - recall_1: 0.8603 - val_loss: 0.3659 - val_binary_accuracy: 0.8507 - val_precision_1: 0.9044 - val_recall_1: 0.8039
# Epoch 4/30
# 70/70 [==============================] - 59s 845ms/step - loss: 0.2696 - binary_accuracy: 0.8991 - precision_1: 0.9184 - recall_1: 0.8695 - val_loss: 0.3381 - val_binary_accuracy: 0.8542 - val_precision_1: 0.8675 - val_recall_1: 0.8562
# Epoch 5/30
# 70/70 [==============================] - 61s 878ms/step - loss: 0.2224 - binary_accuracy: 0.9161 - precision_1: 0.9327 - recall_1: 0.8915 - val_loss: 0.2929 - val_binary_accuracy: 0.8507 - val_precision_1: 0.9435 - val_recall_1: 0.7647
# Epoch 6/30
# 70/70 [==============================] - 60s 865ms/step - loss: 0.2289 - binary_accuracy: 0.9107 - precision_1: 0.9269 - recall_1: 0.8860 - val_loss: 0.2633 - val_binary_accuracy: 0.8750 - val_precision_1: 0.9466 - val_recall_1: 0.8105
# Epoch 7/30
# 70/70 [==============================] - 47s 673ms/step - loss: 0.2213 - binary_accuracy: 0.9098 - precision_1: 0.9156 - recall_1: 0.8971 - val_loss: 0.2789 - val_binary_accuracy: 0.8785 - val_precision_1: 0.8986 - val_recall_1: 0.8693
# Epoch 8/30
# 70/70 [==============================] - 66s 952ms/step - loss: 0.1885 - binary_accuracy: 0.9250 - precision_1: 0.9228 - recall_1: 0.9228 - val_loss: 0.2341 - val_binary_accuracy: 0.9062 - val_precision_1: 0.9437 - val_recall_1: 0.8758
# Epoch 9/30
# 70/70 [==============================] - 45s 648ms/step - loss: 0.1610 - binary_accuracy: 0.9366 - precision_1: 0.9388 - recall_1: 0.9301 - val_loss: 0.2572 - val_binary_accuracy: 0.8958 - val_precision_1: 0.9301 - val_recall_1: 0.8693
# Epoch 10/30
# 70/70 [==============================] - 44s 635ms/step - loss: 0.1519 - binary_accuracy: 0.9402 - precision_1: 0.9509 - recall_1: 0.9246 - val_loss: 0.2797 - val_binary_accuracy: 0.9132 - val_precision_1: 0.9706 - val_recall_1: 0.8627
# Epoch 11/30
# 70/70 [==============================] - 44s 635ms/step - loss: 0.1177 - binary_accuracy: 0.9473 - precision_1: 0.9567 - recall_1: 0.9338 - val_loss: 0.2468 - val_binary_accuracy: 0.9028 - val_precision_1: 0.9433 - val_recall_1: 0.8693
# Epoch 12/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.1251 - binary_accuracy: 0.9446 - precision_1: 0.9430 - recall_1: 0.9430 - val_loss: 0.4268 - val_binary_accuracy: 0.8750 - val_precision_1: 0.8545 - val_recall_1: 0.9216
# Epoch 13/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.1282 - binary_accuracy: 0.9545 - precision_1: 0.9660 - recall_1: 0.9393 - val_loss: 0.3277 - val_binary_accuracy: 0.8993 - val_precision_1: 0.9697 - val_recall_1: 0.8366
# Epoch 14/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.1291 - binary_accuracy: 0.9518 - precision_1: 0.9623 - recall_1: 0.9375 - val_loss: 0.2807 - val_binary_accuracy: 0.9028 - val_precision_1: 0.9032 - val_recall_1: 0.9150
# Epoch 15/30
# 70/70 [==============================] - 44s 635ms/step - loss: 0.0990 - binary_accuracy: 0.9616 - precision_1: 0.9630 - recall_1: 0.9577 - val_loss: 0.5545 - val_binary_accuracy: 0.9062 - val_precision_1: 0.9257 - val_recall_1: 0.8954
# Epoch 16/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.1061 - binary_accuracy: 0.9607 - precision_1: 0.9613 - recall_1: 0.9577 - val_loss: 0.2647 - val_binary_accuracy: 0.9028 - val_precision_1: 0.8981 - val_recall_1: 0.9216
# Epoch 17/30
# 70/70 [==============================] - 44s 635ms/step - loss: 0.0795 - binary_accuracy: 0.9759 - precision_1: 0.9726 - recall_1: 0.9779 - val_loss: 0.4616 - val_binary_accuracy: 0.9132 - val_precision_1: 0.9384 - val_recall_1: 0.8954
# Epoch 18/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0729 - binary_accuracy: 0.9723 - precision_1: 0.9724 - recall_1: 0.9706Restoring model weights from the end of the best epoch: 8.
# 70/70 [==============================] - 45s 642ms/step - loss: 0.0729 - binary_accuracy: 0.9723 - precision_1: 0.9724 - recall_1: 0.9706 - val_loss: 0.3191 - val_binary_accuracy: 0.9236 - val_precision_1: 0.9580 - val_recall_1: 0.8954
# Epoch 00018: early stopping
# fold 0 f1: 0.8994082840236686
# FOLD 1
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
#
#  dense (Dense)               (None, 512)               95158784
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 149,496,033
# Trainable params: 95,159,297
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 97s 794ms/step - loss: 78.0234 - binary_accuracy: 0.7570 - precision: 0.7608 - recall: 0.7688 - val_loss: 12.7851 - val_binary_accuracy: 0.8125 - val_precision: 0.8621 - val_recall: 0.7246
# Epoch 2/30
# 70/70 [==============================] - 29s 420ms/step - loss: 10.7595 - binary_accuracy: 0.8128 - precision: 0.8157 - recall: 0.8214 - val_loss: 2.3069 - val_binary_accuracy: 0.8299 - val_precision: 0.7908 - val_recall: 0.8768
# Epoch 3/30
# 70/70 [==============================] - 27s 389ms/step - loss: 2.5128 - binary_accuracy: 0.8191 - precision: 0.8234 - recall: 0.8249 - val_loss: 1.0851 - val_binary_accuracy: 0.8125 - val_precision: 0.7763 - val_recall: 0.8551
# Epoch 4/30
# 70/70 [==============================] - 26s 376ms/step - loss: 1.2007 - binary_accuracy: 0.8101 - precision: 0.8061 - recall: 0.8301 - val_loss: 0.8478 - val_binary_accuracy: 0.7986 - val_precision: 0.8030 - val_recall: 0.7681
# Epoch 5/30
# 70/70 [==============================] - 26s 371ms/step - loss: 0.8992 - binary_accuracy: 0.8038 - precision: 0.8146 - recall: 0.8004 - val_loss: 0.7589 - val_binary_accuracy: 0.8333 - val_precision: 0.8000 - val_recall: 0.8696
# Epoch 6/30
# 70/70 [==============================] - 26s 373ms/step - loss: 0.9320 - binary_accuracy: 0.8335 - precision: 0.8496 - recall: 0.8214 - val_loss: 0.6365 - val_binary_accuracy: 0.8368 - val_precision: 0.8227 - val_recall: 0.8406
# Epoch 7/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.9064 - binary_accuracy: 0.8155 - precision: 0.8268 - recall: 0.8109 - val_loss: 0.6015 - val_binary_accuracy: 0.8438 - val_precision: 0.8121 - val_recall: 0.8768
# Epoch 8/30
# 70/70 [==============================] - 26s 373ms/step - loss: 0.7959 - binary_accuracy: 0.8128 - precision: 0.8259 - recall: 0.8056 - val_loss: 0.5794 - val_binary_accuracy: 0.8542 - val_precision: 0.8478 - val_recall: 0.8478
# Epoch 9/30
# 70/70 [==============================] - 26s 373ms/step - loss: 0.8713 - binary_accuracy: 0.8200 - precision: 0.8193 - recall: 0.8336 - val_loss: 0.5676 - val_binary_accuracy: 0.8681 - val_precision: 0.8521 - val_recall: 0.8768
# Epoch 10/30
# 70/70 [==============================] - 26s 371ms/step - loss: 0.7039 - binary_accuracy: 0.8182 - precision: 0.8209 - recall: 0.8266 - val_loss: 0.5601 - val_binary_accuracy: 0.8507 - val_precision: 0.8519 - val_recall: 0.8333
# Epoch 11/30
# 70/70 [==============================] - 26s 376ms/step - loss: 0.7139 - binary_accuracy: 0.8164 - precision: 0.8318 - recall: 0.8056 - val_loss: 0.5557 - val_binary_accuracy: 0.8507 - val_precision: 0.8467 - val_recall: 0.8406
# Epoch 12/30
# 70/70 [==============================] - 29s 412ms/step - loss: 0.5779 - binary_accuracy: 0.8344 - precision: 0.8425 - recall: 0.8336 - val_loss: 0.5536 - val_binary_accuracy: 0.8507 - val_precision: 0.8467 - val_recall: 0.8406
# Epoch 13/30
# 70/70 [==============================] - 27s 381ms/step - loss: 0.7258 - binary_accuracy: 0.8182 - precision: 0.8243 - recall: 0.8214 - val_loss: 0.5526 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 14/30
# 70/70 [==============================] - 26s 380ms/step - loss: 0.5235 - binary_accuracy: 0.8371 - precision: 0.8433 - recall: 0.8389 - val_loss: 0.5523 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 15/30
# 70/70 [==============================] - 26s 376ms/step - loss: 0.7707 - binary_accuracy: 0.8335 - precision: 0.8522 - recall: 0.8179 - val_loss: 0.5520 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 16/30
# 70/70 [==============================] - 26s 378ms/step - loss: 0.7471 - binary_accuracy: 0.8110 - precision: 0.8217 - recall: 0.8074 - val_loss: 0.5518 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 17/30
# 70/70 [==============================] - 29s 414ms/step - loss: 0.6899 - binary_accuracy: 0.8308 - precision: 0.8488 - recall: 0.8161 - val_loss: 0.5517 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 18/30
# 70/70 [==============================] - 26s 379ms/step - loss: 0.7150 - binary_accuracy: 0.8191 - precision: 0.8201 - recall: 0.8301 - val_loss: 0.5517 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 19/30
# 70/70 [==============================] - 26s 378ms/step - loss: 0.7374 - binary_accuracy: 0.8290 - precision: 0.8384 - recall: 0.8266 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 20/30
# 70/70 [==============================] - 26s 373ms/step - loss: 0.7000 - binary_accuracy: 0.8182 - precision: 0.8336 - recall: 0.8074 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 21/30
# 70/70 [==============================] - 26s 380ms/step - loss: 0.7522 - binary_accuracy: 0.8281 - precision: 0.8393 - recall: 0.8231 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 22/30
# 70/70 [==============================] - 26s 380ms/step - loss: 0.6372 - binary_accuracy: 0.8236 - precision: 0.8272 - recall: 0.8301 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 23/30
# 70/70 [==============================] - 28s 407ms/step - loss: 0.7661 - binary_accuracy: 0.8218 - precision: 0.8447 - recall: 0.8004 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 24/30
# 70/70 [==============================] - 27s 384ms/step - loss: 0.7411 - binary_accuracy: 0.8110 - precision: 0.8206 - recall: 0.8091 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 25/30
# 70/70 [==============================] - 27s 383ms/step - loss: 0.8500 - binary_accuracy: 0.8137 - precision: 0.8216 - recall: 0.8144 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 26/30
# 70/70 [==============================] - 16s 236ms/step - loss: 0.7443 - binary_accuracy: 0.8263 - precision: 0.8375 - recall: 0.8214 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 27/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.7163 - binary_accuracy: 0.8191 - precision: 0.8246 - recall: 0.8231 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 28/30
# 70/70 [==============================] - 27s 385ms/step - loss: 0.6528 - binary_accuracy: 0.8182 - precision: 0.8231 - recall: 0.8231 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 29/30
# 70/70 [==============================] - 27s 386ms/step - loss: 0.6584 - binary_accuracy: 0.8389 - precision: 0.8551 - recall: 0.8266 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Epoch 30/30
# 70/70 [==============================] - 26s 380ms/step - loss: 0.7539 - binary_accuracy: 0.8155 - precision: 0.8303 - recall: 0.8056 - val_loss: 0.5516 - val_binary_accuracy: 0.8542 - val_precision: 0.8529 - val_recall: 0.8406
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
#
#  dense (Dense)               (None, 512)               95158784
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 149,496,033
# Trainable params: 149,435,489
# Non-trainable params: 60,544
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 95s 937ms/step - loss: 0.5604 - binary_accuracy: 0.7732 - precision_1: 0.8121 - recall_1: 0.7268 - val_loss: 0.5012 - val_binary_accuracy: 0.7951 - val_precision_1: 0.7207 - val_recall_1: 0.9348
# Epoch 2/30
# 70/70 [==============================] - 76s 1s/step - loss: 0.4652 - binary_accuracy: 0.8308 - precision_1: 0.8676 - recall_1: 0.7916 - val_loss: 0.3283 - val_binary_accuracy: 0.8576 - val_precision_1: 0.8593 - val_recall_1: 0.8406
# Epoch 3/30
# 70/70 [==============================] - 61s 870ms/step - loss: 0.3441 - binary_accuracy: 0.8605 - precision_1: 0.8925 - recall_1: 0.8284 - val_loss: 0.2813 - val_binary_accuracy: 0.8785 - val_precision_1: 0.8366 - val_recall_1: 0.9275
# Epoch 4/30
# 70/70 [==============================] - 62s 892ms/step - loss: 0.2772 - binary_accuracy: 0.8911 - precision_1: 0.9047 - recall_1: 0.8809 - val_loss: 0.2389 - val_binary_accuracy: 0.9028 - val_precision_1: 0.9104 - val_recall_1: 0.8841
# Epoch 5/30
# 70/70 [==============================] - 47s 676ms/step - loss: 0.2227 - binary_accuracy: 0.9127 - precision_1: 0.9357 - recall_1: 0.8914 - val_loss: 0.3223 - val_binary_accuracy: 0.8785 - val_precision_1: 0.8366 - val_recall_1: 0.9275
# Epoch 6/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.2373 - binary_accuracy: 0.9064 - precision_1: 0.9238 - recall_1: 0.8914 - val_loss: 0.4001 - val_binary_accuracy: 0.8507 - val_precision_1: 0.8105 - val_recall_1: 0.8986
# Epoch 7/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.2452 - binary_accuracy: 0.8974 - precision_1: 0.9030 - recall_1: 0.8967 - val_loss: 0.2502 - val_binary_accuracy: 0.8958 - val_precision_1: 0.8913 - val_recall_1: 0.8913
# Epoch 8/30
# 70/70 [==============================] - 72s 1s/step - loss: 0.1863 - binary_accuracy: 0.9190 - precision_1: 0.9197 - recall_1: 0.9229 - val_loss: 0.2338 - val_binary_accuracy: 0.9132 - val_precision_1: 0.9185 - val_recall_1: 0.8986
# Epoch 9/30
# 70/70 [==============================] - 45s 644ms/step - loss: 0.1671 - binary_accuracy: 0.9298 - precision_1: 0.9425 - recall_1: 0.9194 - val_loss: 0.3985 - val_binary_accuracy: 0.8611 - val_precision_1: 0.8101 - val_recall_1: 0.9275
# Epoch 10/30
# 70/70 [==============================] - 44s 633ms/step - loss: 0.2013 - binary_accuracy: 0.9163 - precision_1: 0.9135 - recall_1: 0.9247 - val_loss: 0.2383 - val_binary_accuracy: 0.9097 - val_precision_1: 0.9179 - val_recall_1: 0.8913
# Epoch 11/30
# 70/70 [==============================] - 44s 633ms/step - loss: 0.1393 - binary_accuracy: 0.9397 - precision_1: 0.9452 - recall_1: 0.9370 - val_loss: 0.2874 - val_binary_accuracy: 0.8750 - val_precision_1: 0.8269 - val_recall_1: 0.9348
# Epoch 12/30
# 70/70 [==============================] - 67s 962ms/step - loss: 0.1436 - binary_accuracy: 0.9478 - precision_1: 0.9556 - recall_1: 0.9422 - val_loss: 0.2169 - val_binary_accuracy: 0.9201 - val_precision_1: 0.8912 - val_recall_1: 0.9493
# Epoch 13/30
# 70/70 [==============================] - 69s 988ms/step - loss: 0.1342 - binary_accuracy: 0.9469 - precision_1: 0.9429 - recall_1: 0.9545 - val_loss: 0.2016 - val_binary_accuracy: 0.9236 - val_precision_1: 0.9203 - val_recall_1: 0.9203
# Epoch 14/30
# 70/70 [==============================] - 47s 672ms/step - loss: 0.1147 - binary_accuracy: 0.9595 - precision_1: 0.9663 - recall_1: 0.9545 - val_loss: 0.2165 - val_binary_accuracy: 0.9306 - val_precision_1: 0.9470 - val_recall_1: 0.9058
# Epoch 15/30
# 70/70 [==============================] - 44s 633ms/step - loss: 0.1187 - binary_accuracy: 0.9568 - precision_1: 0.9580 - recall_1: 0.9580 - val_loss: 0.2109 - val_binary_accuracy: 0.9097 - val_precision_1: 0.8684 - val_recall_1: 0.9565
# Epoch 16/30
# 70/70 [==============================] - 70s 999ms/step - loss: 0.1343 - binary_accuracy: 0.9397 - precision_1: 0.9360 - recall_1: 0.9475 - val_loss: 0.1924 - val_binary_accuracy: 0.9271 - val_precision_1: 0.9034 - val_recall_1: 0.9493
# Epoch 17/30
# 70/70 [==============================] - 45s 646ms/step - loss: 0.1069 - binary_accuracy: 0.9595 - precision_1: 0.9630 - recall_1: 0.9580 - val_loss: 0.2215 - val_binary_accuracy: 0.9514 - val_precision_1: 0.9627 - val_recall_1: 0.9348
# Epoch 18/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.0887 - binary_accuracy: 0.9577 - precision_1: 0.9580 - recall_1: 0.9597 - val_loss: 0.2083 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9231 - val_recall_1: 0.9565
# Epoch 19/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.0814 - binary_accuracy: 0.9658 - precision_1: 0.9667 - recall_1: 0.9667 - val_loss: 0.2224 - val_binary_accuracy: 0.9514 - val_precision_1: 0.9627 - val_recall_1: 0.9348
# Epoch 20/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.0578 - binary_accuracy: 0.9766 - precision_1: 0.9739 - recall_1: 0.9807 - val_loss: 0.2756 - val_binary_accuracy: 0.9514 - val_precision_1: 0.9627 - val_recall_1: 0.9348
# Epoch 21/30
# 70/70 [==============================] - 44s 633ms/step - loss: 0.0644 - binary_accuracy: 0.9766 - precision_1: 0.9772 - recall_1: 0.9772 - val_loss: 0.2413 - val_binary_accuracy: 0.9444 - val_precision_1: 0.9420 - val_recall_1: 0.9420
# Epoch 22/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.0532 - binary_accuracy: 0.9793 - precision_1: 0.9790 - recall_1: 0.9807 - val_loss: 0.2365 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9353 - val_recall_1: 0.9420
# Epoch 23/30
# 70/70 [==============================] - 44s 633ms/step - loss: 0.0376 - binary_accuracy: 0.9847 - precision_1: 0.9809 - recall_1: 0.9895 - val_loss: 0.2963 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9286 - val_recall_1: 0.9420
# Epoch 24/30
# 70/70 [==============================] - 44s 633ms/step - loss: 0.0361 - binary_accuracy: 0.9883 - precision_1: 0.9878 - recall_1: 0.9895 - val_loss: 0.2842 - val_binary_accuracy: 0.9514 - val_precision_1: 0.9697 - val_recall_1: 0.9275
# Epoch 25/30
# 70/70 [==============================] - 44s 634ms/step - loss: 0.0600 - binary_accuracy: 0.9775 - precision_1: 0.9756 - recall_1: 0.9807 - val_loss: 0.2600 - val_binary_accuracy: 0.9444 - val_precision_1: 0.9621 - val_recall_1: 0.9203
# Epoch 26/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0366 - binary_accuracy: 0.9883 - precision_1: 0.9878 - recall_1: 0.9895Restoring model weights from the end of the best epoch: 16.
# 70/70 [==============================] - 45s 642ms/step - loss: 0.0366 - binary_accuracy: 0.9883 - precision_1: 0.9878 - recall_1: 0.9895 - val_loss: 0.3152 - val_binary_accuracy: 0.9514 - val_precision_1: 0.9697 - val_recall_1: 0.9275
# Epoch 00026: early stopping
# fold 1 f1: 0.9261363636363638
# FOLD 2
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
#
#  dense (Dense)               (None, 512)               95158784
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 149,496,033
# Trainable params: 95,159,297
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 98s 800ms/step - loss: 102.8020 - binary_accuracy: 0.7156 - precision: 0.7051 - recall: 0.7130 - val_loss: 12.1578 - val_binary_accuracy: 0.8264 - val_precision: 0.8037 - val_recall: 0.8792
# Epoch 2/30
# 70/70 [==============================] - 27s 392ms/step - loss: 8.3733 - binary_accuracy: 0.7939 - precision: 0.7853 - recall: 0.7926 - val_loss: 1.5828 - val_binary_accuracy: 0.8403 - val_precision: 0.7977 - val_recall: 0.9262
# Epoch 3/30
# 70/70 [==============================] - 26s 376ms/step - loss: 2.9199 - binary_accuracy: 0.7939 - precision: 0.7864 - recall: 0.7907 - val_loss: 1.1867 - val_binary_accuracy: 0.8194 - val_precision: 0.7836 - val_recall: 0.8993
# Epoch 4/30
# 70/70 [==============================] - 27s 385ms/step - loss: 1.7944 - binary_accuracy: 0.8002 - precision: 0.8000 - recall: 0.7852 - val_loss: 0.6954 - val_binary_accuracy: 0.8333 - val_precision: 0.8797 - val_recall: 0.7852
# Epoch 5/30
# 70/70 [==============================] - 27s 386ms/step - loss: 1.2503 - binary_accuracy: 0.7957 - precision: 0.7800 - recall: 0.8074 - val_loss: 0.6257 - val_binary_accuracy: 0.8472 - val_precision: 0.8889 - val_recall: 0.8054
# Epoch 6/30
# 70/70 [==============================] - 29s 420ms/step - loss: 0.9527 - binary_accuracy: 0.8002 - precision: 0.8011 - recall: 0.7833 - val_loss: 0.5792 - val_binary_accuracy: 0.8576 - val_precision: 0.8971 - val_recall: 0.8188
# Epoch 7/30
# 70/70 [==============================] - 26s 372ms/step - loss: 0.8477 - binary_accuracy: 0.8029 - precision: 0.8166 - recall: 0.7667 - val_loss: 0.5566 - val_binary_accuracy: 0.8576 - val_precision: 0.8699 - val_recall: 0.8523
# Epoch 8/30
# 70/70 [==============================] - 26s 374ms/step - loss: 1.0644 - binary_accuracy: 0.8137 - precision: 0.8136 - recall: 0.8000 - val_loss: 0.5485 - val_binary_accuracy: 0.8438 - val_precision: 0.8662 - val_recall: 0.8255
# Epoch 9/30
# 70/70 [==============================] - 26s 377ms/step - loss: 0.8802 - binary_accuracy: 0.8083 - precision: 0.8056 - recall: 0.7981 - val_loss: 0.5435 - val_binary_accuracy: 0.8333 - val_precision: 0.8633 - val_recall: 0.8054
# Epoch 10/30
# 70/70 [==============================] - 28s 406ms/step - loss: 0.8064 - binary_accuracy: 0.8119 - precision: 0.8152 - recall: 0.7926 - val_loss: 0.5434 - val_binary_accuracy: 0.8333 - val_precision: 0.8633 - val_recall: 0.8054
# Epoch 11/30
# 70/70 [==============================] - 26s 372ms/step - loss: 0.9981 - binary_accuracy: 0.7885 - precision: 0.7728 - recall: 0.8000 - val_loss: 0.5399 - val_binary_accuracy: 0.8368 - val_precision: 0.8643 - val_recall: 0.8121
# Epoch 12/30
# 70/70 [==============================] - 29s 420ms/step - loss: 0.7761 - binary_accuracy: 0.8137 - precision: 0.8124 - recall: 0.8019 - val_loss: 0.5392 - val_binary_accuracy: 0.8299 - val_precision: 0.8623 - val_recall: 0.7987
# Epoch 13/30
# 70/70 [==============================] - 26s 376ms/step - loss: 1.1790 - binary_accuracy: 0.8056 - precision: 0.8115 - recall: 0.7815 - val_loss: 0.5386 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 14/30
# 70/70 [==============================] - 26s 371ms/step - loss: 0.9388 - binary_accuracy: 0.8047 - precision: 0.8041 - recall: 0.7907 - val_loss: 0.5380 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 15/30
# 70/70 [==============================] - 25s 366ms/step - loss: 0.8345 - binary_accuracy: 0.7966 - precision: 0.7996 - recall: 0.7759 - val_loss: 0.5377 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 16/30
# 70/70 [==============================] - 25s 367ms/step - loss: 0.9169 - binary_accuracy: 0.8110 - precision: 0.8149 - recall: 0.7907 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 17/30
# 70/70 [==============================] - 26s 367ms/step - loss: 0.8821 - binary_accuracy: 0.8092 - precision: 0.8004 - recall: 0.8093 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 18/30
# 70/70 [==============================] - 17s 240ms/step - loss: 0.7900 - binary_accuracy: 0.8191 - precision: 0.8304 - recall: 0.7889 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 19/30
# 70/70 [==============================] - 27s 389ms/step - loss: 0.9441 - binary_accuracy: 0.8038 - precision: 0.8049 - recall: 0.7870 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 20/30
# 70/70 [==============================] - 17s 245ms/step - loss: 0.8954 - binary_accuracy: 0.8038 - precision: 0.8084 - recall: 0.7815 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 21/30
# 70/70 [==============================] - 30s 438ms/step - loss: 0.8722 - binary_accuracy: 0.8101 - precision: 0.8121 - recall: 0.7926 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 22/30
# 70/70 [==============================] - 27s 389ms/step - loss: 0.8164 - binary_accuracy: 0.8119 - precision: 0.8140 - recall: 0.7944 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 23/30
# 70/70 [==============================] - 28s 409ms/step - loss: 0.9149 - binary_accuracy: 0.8011 - precision: 0.8061 - recall: 0.7778 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 24/30
# 70/70 [==============================] - 17s 240ms/step - loss: 0.9221 - binary_accuracy: 0.7984 - precision: 0.7970 - recall: 0.7852 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 25/30
# 70/70 [==============================] - 27s 383ms/step - loss: 0.8698 - binary_accuracy: 0.8029 - precision: 0.8104 - recall: 0.7759 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 26/30
# 70/70 [==============================] - 17s 243ms/step - loss: 0.8832 - binary_accuracy: 0.8155 - precision: 0.8240 - recall: 0.7889 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 27/30
# 70/70 [==============================] - 17s 246ms/step - loss: 0.9841 - binary_accuracy: 0.7930 - precision: 0.7936 - recall: 0.7759 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 28/30
# 70/70 [==============================] - 16s 233ms/step - loss: 0.9048 - binary_accuracy: 0.8173 - precision: 0.8150 - recall: 0.8074 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 29/30
# 70/70 [==============================] - 16s 232ms/step - loss: 0.7506 - binary_accuracy: 0.8011 - precision: 0.7992 - recall: 0.7889 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 30/30
# 70/70 [==============================] - ETA: 0s - loss: 0.9871 - binary_accuracy: 0.8056 - precision: 0.8034 - recall: 0.7944Restoring model weights from the end of the best epoch: 25.
# 70/70 [==============================] - 17s 240ms/step - loss: 0.9871 - binary_accuracy: 0.8056 - precision: 0.8034 - recall: 0.7944 - val_loss: 0.5376 - val_binary_accuracy: 0.8333 - val_precision: 0.8686 - val_recall: 0.7987
# Epoch 00030: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
#
#  dense (Dense)               (None, 512)               95158784
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 149,496,033
# Trainable params: 149,435,489
# Non-trainable params: 60,544
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 89s 946ms/step - loss: 0.7717 - binary_accuracy: 0.7507 - precision_1: 0.7594 - recall_1: 0.7130 - val_loss: 0.3101 - val_binary_accuracy: 0.8507 - val_precision_1: 0.8786 - val_recall_1: 0.8255
# Epoch 2/30
# 70/70 [==============================] - 45s 644ms/step - loss: 0.5178 - binary_accuracy: 0.7750 - precision_1: 0.7900 - recall_1: 0.7315 - val_loss: 0.3698 - val_binary_accuracy: 0.8542 - val_precision_1: 0.8905 - val_recall_1: 0.8188
# Epoch 3/30
# 70/70 [==============================] - 74s 1s/step - loss: 0.3982 - binary_accuracy: 0.8578 - precision_1: 0.8687 - recall_1: 0.8333 - val_loss: 0.2939 - val_binary_accuracy: 0.8681 - val_precision_1: 0.8828 - val_recall_1: 0.8591
# Epoch 4/30
# 70/70 [==============================] - 60s 865ms/step - loss: 0.3554 - binary_accuracy: 0.8569 - precision_1: 0.8561 - recall_1: 0.8481 - val_loss: 0.2724 - val_binary_accuracy: 0.8819 - val_precision_1: 0.9323 - val_recall_1: 0.8322
# Epoch 5/30
# 70/70 [==============================] - 75s 1s/step - loss: 0.2936 - binary_accuracy: 0.8686 - precision_1: 0.8774 - recall_1: 0.8481 - val_loss: 0.2563 - val_binary_accuracy: 0.8924 - val_precision_1: 0.9275 - val_recall_1: 0.8591
# Epoch 6/30
# 70/70 [==============================] - 45s 650ms/step - loss: 0.2734 - binary_accuracy: 0.8911 - precision_1: 0.9006 - recall_1: 0.8722 - val_loss: 0.3214 - val_binary_accuracy: 0.8646 - val_precision_1: 0.9297 - val_recall_1: 0.7987
# Epoch 7/30
# 70/70 [==============================] - 71s 1s/step - loss: 0.2465 - binary_accuracy: 0.9019 - precision_1: 0.8954 - recall_1: 0.9037 - val_loss: 0.2101 - val_binary_accuracy: 0.9167 - val_precision_1: 0.9195 - val_recall_1: 0.9195
# Epoch 8/30
# 70/70 [==============================] - 45s 649ms/step - loss: 0.2410 - binary_accuracy: 0.9091 - precision_1: 0.9103 - recall_1: 0.9019 - val_loss: 0.2138 - val_binary_accuracy: 0.9201 - val_precision_1: 0.9257 - val_recall_1: 0.9195
# Epoch 9/30
# 70/70 [==============================] - 67s 955ms/step - loss: 0.2163 - binary_accuracy: 0.9154 - precision_1: 0.9114 - recall_1: 0.9148 - val_loss: 0.1800 - val_binary_accuracy: 0.9306 - val_precision_1: 0.9388 - val_recall_1: 0.9262
# Epoch 10/30
# 70/70 [==============================] - 45s 650ms/step - loss: 0.1749 - binary_accuracy: 0.9262 - precision_1: 0.9321 - recall_1: 0.9148 - val_loss: 0.2177 - val_binary_accuracy: 0.8924 - val_precision_1: 0.9214 - val_recall_1: 0.8658
# Epoch 11/30
# 70/70 [==============================] - 45s 638ms/step - loss: 0.1881 - binary_accuracy: 0.9298 - precision_1: 0.9375 - recall_1: 0.9167 - val_loss: 0.2134 - val_binary_accuracy: 0.8958 - val_precision_1: 0.9612 - val_recall_1: 0.8322
# Epoch 12/30
# 70/70 [==============================] - 45s 637ms/step - loss: 0.1557 - binary_accuracy: 0.9406 - precision_1: 0.9357 - recall_1: 0.9426 - val_loss: 0.2102 - val_binary_accuracy: 0.9097 - val_precision_1: 0.9489 - val_recall_1: 0.8725
# Epoch 13/30
# 70/70 [==============================] - 67s 958ms/step - loss: 0.1541 - binary_accuracy: 0.9307 - precision_1: 0.9263 - recall_1: 0.9315 - val_loss: 0.1792 - val_binary_accuracy: 0.9236 - val_precision_1: 0.9150 - val_recall_1: 0.9396
# Epoch 14/30
# 70/70 [==============================] - 45s 645ms/step - loss: 0.1463 - binary_accuracy: 0.9415 - precision_1: 0.9541 - recall_1: 0.9241 - val_loss: 0.1850 - val_binary_accuracy: 0.9201 - val_precision_1: 0.9437 - val_recall_1: 0.8993
# Epoch 15/30
# 70/70 [==============================] - 44s 635ms/step - loss: 0.1149 - binary_accuracy: 0.9559 - precision_1: 0.9472 - recall_1: 0.9630 - val_loss: 0.2142 - val_binary_accuracy: 0.9167 - val_precision_1: 0.9562 - val_recall_1: 0.8792
# Epoch 16/30
# 70/70 [==============================] - 44s 636ms/step - loss: 0.1151 - binary_accuracy: 0.9523 - precision_1: 0.9568 - recall_1: 0.9444 - val_loss: 0.1878 - val_binary_accuracy: 0.9201 - val_precision_1: 0.9437 - val_recall_1: 0.8993
# Epoch 17/30
# 70/70 [==============================] - 45s 637ms/step - loss: 0.1374 - binary_accuracy: 0.9532 - precision_1: 0.9535 - recall_1: 0.9500 - val_loss: 0.2111 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9514 - val_recall_1: 0.9195
# Epoch 18/30
# 70/70 [==============================] - 66s 953ms/step - loss: 0.1137 - binary_accuracy: 0.9514 - precision_1: 0.9568 - recall_1: 0.9426 - val_loss: 0.1710 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9648 - val_recall_1: 0.9195
# Epoch 19/30
# 70/70 [==============================] - 67s 967ms/step - loss: 0.1074 - binary_accuracy: 0.9667 - precision_1: 0.9701 - recall_1: 0.9611 - val_loss: 0.1709 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9779 - val_recall_1: 0.8926
# Epoch 20/30
# 70/70 [==============================] - 46s 652ms/step - loss: 0.0910 - binary_accuracy: 0.9667 - precision_1: 0.9683 - recall_1: 0.9630 - val_loss: 0.1822 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9514 - val_recall_1: 0.9195
# Epoch 21/30
# 70/70 [==============================] - 45s 637ms/step - loss: 0.0793 - binary_accuracy: 0.9694 - precision_1: 0.9738 - recall_1: 0.9630 - val_loss: 0.1949 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9710 - val_recall_1: 0.8993
# Epoch 22/30
# 70/70 [==============================] - 44s 636ms/step - loss: 0.0785 - binary_accuracy: 0.9721 - precision_1: 0.9722 - recall_1: 0.9704 - val_loss: 0.1742 - val_binary_accuracy: 0.9479 - val_precision_1: 0.9589 - val_recall_1: 0.9396
# Epoch 23/30
# 70/70 [==============================] - 47s 667ms/step - loss: 0.0638 - binary_accuracy: 0.9775 - precision_1: 0.9690 - recall_1: 0.9852 - val_loss: 0.2003 - val_binary_accuracy: 0.9479 - val_precision_1: 0.9653 - val_recall_1: 0.9329
# Epoch 24/30
# 70/70 [==============================] - 45s 636ms/step - loss: 0.0536 - binary_accuracy: 0.9775 - precision_1: 0.9777 - recall_1: 0.9759 - val_loss: 0.2528 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9853 - val_recall_1: 0.8993
# Epoch 25/30
# 70/70 [==============================] - 45s 637ms/step - loss: 0.0683 - binary_accuracy: 0.9784 - precision_1: 0.9778 - recall_1: 0.9778 - val_loss: 0.2533 - val_binary_accuracy: 0.9306 - val_precision_1: 0.9574 - val_recall_1: 0.9060
# Epoch 26/30
# 70/70 [==============================] - 45s 637ms/step - loss: 0.0501 - binary_accuracy: 0.9820 - precision_1: 0.9815 - recall_1: 0.9815 - val_loss: 0.2695 - val_binary_accuracy: 0.9479 - val_precision_1: 0.9653 - val_recall_1: 0.9329
# Epoch 27/30
# 70/70 [==============================] - 45s 638ms/step - loss: 0.0528 - binary_accuracy: 0.9775 - precision_1: 0.9795 - recall_1: 0.9741 - val_loss: 0.2682 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9710 - val_recall_1: 0.8993
# Epoch 28/30
# 70/70 [==============================] - 44s 636ms/step - loss: 0.0290 - binary_accuracy: 0.9928 - precision_1: 0.9926 - recall_1: 0.9926 - val_loss: 0.2491 - val_binary_accuracy: 0.9444 - val_precision_1: 0.9716 - val_recall_1: 0.9195
# Epoch 29/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0336 - binary_accuracy: 0.9874 - precision_1: 0.9870 - recall_1: 0.9870Restoring model weights from the end of the best epoch: 19.
# 70/70 [==============================] - 45s 645ms/step - loss: 0.0336 - binary_accuracy: 0.9874 - precision_1: 0.9870 - recall_1: 0.9870 - val_loss: 0.3293 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9853 - val_recall_1: 0.8993
# Epoch 00029: early stopping
# fold 2 f1: 0.9485094850948509
# FOLD 3
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
# ...
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
#
#  dense (Dense)               (None, 512)               95158784
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 149,496,033
# Trainable params: 95,159,297
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 97s 795ms/step - loss: 124.7030 - binary_accuracy: 0.7384 - precision: 0.7266 - recall: 0.7333 - val_loss: 35.5791 - val_binary_accuracy: 0.8403 - val_precision: 0.8118 - val_recall: 0.9079
# Epoch 2/30
# 70/70 [==============================] - 27s 392ms/step - loss: 23.0080 - binary_accuracy: 0.8054 - precision: 0.7981 - recall: 0.7981 - val_loss: 9.3553 - val_binary_accuracy: 0.8229 - val_precision: 0.8582 - val_recall: 0.7961
# Epoch 3/30
# 70/70 [==============================] - 27s 385ms/step - loss: 6.8164 - binary_accuracy: 0.8179 - precision: 0.8134 - recall: 0.8074 - val_loss: 4.5296 - val_binary_accuracy: 0.8438 - val_precision: 0.8282 - val_recall: 0.8882
# Epoch 4/30
# 70/70 [==============================] - 27s 386ms/step - loss: 3.4433 - binary_accuracy: 0.8062 - precision: 0.7952 - recall: 0.8056 - val_loss: 3.0987 - val_binary_accuracy: 0.8264 - val_precision: 0.8643 - val_recall: 0.7961
# Epoch 5/30
# 70/70 [==============================] - 26s 379ms/step - loss: 2.4174 - binary_accuracy: 0.8232 - precision: 0.8190 - recall: 0.8130 - val_loss: 2.3850 - val_binary_accuracy: 0.8194 - val_precision: 0.8623 - val_recall: 0.7829
# Epoch 6/30
# 70/70 [==============================] - 26s 378ms/step - loss: 1.7296 - binary_accuracy: 0.8348 - precision: 0.8245 - recall: 0.8352 - val_loss: 2.2067 - val_binary_accuracy: 0.8299 - val_precision: 0.8552 - val_recall: 0.8158
# Epoch 7/30
# 70/70 [==============================] - 27s 382ms/step - loss: 1.7957 - binary_accuracy: 0.8223 - precision: 0.8235 - recall: 0.8037 - val_loss: 2.0196 - val_binary_accuracy: 0.8090 - val_precision: 0.8299 - val_recall: 0.8026
# Epoch 8/30
# 70/70 [==============================] - 26s 376ms/step - loss: 1.3417 - binary_accuracy: 0.8491 - precision: 0.8416 - recall: 0.8463 - val_loss: 1.9132 - val_binary_accuracy: 0.8090 - val_precision: 0.8299 - val_recall: 0.8026
# Epoch 9/30
# 70/70 [==============================] - 27s 386ms/step - loss: 1.4616 - binary_accuracy: 0.8214 - precision: 0.8232 - recall: 0.8019 - val_loss: 1.8736 - val_binary_accuracy: 0.8160 - val_precision: 0.8278 - val_recall: 0.8224
# Epoch 10/30
# 70/70 [==============================] - 27s 382ms/step - loss: 1.5241 - binary_accuracy: 0.8455 - precision: 0.8417 - recall: 0.8370 - val_loss: 1.8342 - val_binary_accuracy: 0.8125 - val_precision: 0.8267 - val_recall: 0.8158
# Epoch 11/30
# 70/70 [==============================] - 27s 384ms/step - loss: 1.3737 - binary_accuracy: 0.8339 - precision: 0.8302 - recall: 0.8241 - val_loss: 1.8201 - val_binary_accuracy: 0.8160 - val_precision: 0.8278 - val_recall: 0.8224
# Epoch 12/30
# 70/70 [==============================] - 26s 380ms/step - loss: 1.3514 - binary_accuracy: 0.8384 - precision: 0.8282 - recall: 0.8389 - val_loss: 1.8130 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 13/30
# 70/70 [==============================] - 27s 391ms/step - loss: 1.3742 - binary_accuracy: 0.8429 - precision: 0.8383 - recall: 0.8352 - val_loss: 1.8077 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 14/30
# 70/70 [==============================] - 29s 419ms/step - loss: 1.3208 - binary_accuracy: 0.8339 - precision: 0.8340 - recall: 0.8185 - val_loss: 1.8048 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 15/30
# 70/70 [==============================] - 27s 385ms/step - loss: 1.3336 - binary_accuracy: 0.8357 - precision: 0.8333 - recall: 0.8241 - val_loss: 1.8036 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 16/30
# 70/70 [==============================] - 29s 422ms/step - loss: 1.2224 - binary_accuracy: 0.8509 - precision: 0.8435 - recall: 0.8481 - val_loss: 1.8029 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 17/30
# 70/70 [==============================] - 27s 390ms/step - loss: 1.3378 - binary_accuracy: 0.8152 - precision: 0.8112 - recall: 0.8037 - val_loss: 1.8025 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 18/30
# 70/70 [==============================] - 27s 384ms/step - loss: 1.3539 - binary_accuracy: 0.8313 - precision: 0.8220 - recall: 0.8296 - val_loss: 1.8022 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 19/30
# 70/70 [==============================] - 27s 390ms/step - loss: 1.7015 - binary_accuracy: 0.8384 - precision: 0.8270 - recall: 0.8407 - val_loss: 1.8020 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 20/30
# 70/70 [==============================] - 28s 403ms/step - loss: 1.4790 - binary_accuracy: 0.8357 - precision: 0.8333 - recall: 0.8241 - val_loss: 1.8019 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 21/30
# 70/70 [==============================] - 27s 387ms/step - loss: 1.3725 - binary_accuracy: 0.8313 - precision: 0.8268 - recall: 0.8222 - val_loss: 1.8019 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 22/30
# 70/70 [==============================] - 29s 422ms/step - loss: 1.2195 - binary_accuracy: 0.8500 - precision: 0.8432 - recall: 0.8463 - val_loss: 1.8019 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 23/30
# 70/70 [==============================] - 28s 398ms/step - loss: 1.2667 - binary_accuracy: 0.8330 - precision: 0.8336 - recall: 0.8167 - val_loss: 1.8018 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 24/30
# 70/70 [==============================] - 27s 393ms/step - loss: 1.4334 - binary_accuracy: 0.8438 - precision: 0.8476 - recall: 0.8241 - val_loss: 1.8018 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 25/30
# 70/70 [==============================] - 27s 383ms/step - loss: 1.2861 - binary_accuracy: 0.8393 - precision: 0.8371 - recall: 0.8278 - val_loss: 1.8018 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 26/30
# 70/70 [==============================] - 26s 377ms/step - loss: 1.2215 - binary_accuracy: 0.8375 - precision: 0.8390 - recall: 0.8204 - val_loss: 1.8018 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 27/30
# 70/70 [==============================] - 26s 377ms/step - loss: 1.5684 - binary_accuracy: 0.8250 - precision: 0.8245 - recall: 0.8093 - val_loss: 1.8018 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 28/30
# 70/70 [==============================] - 19s 270ms/step - loss: 1.4646 - binary_accuracy: 0.8259 - precision: 0.8177 - recall: 0.8222 - val_loss: 1.8018 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 29/30
# 70/70 [==============================] - 27s 393ms/step - loss: 1.4586 - binary_accuracy: 0.8375 - precision: 0.8208 - recall: 0.8481 - val_loss: 1.8018 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Epoch 30/30
# 70/70 [==============================] - 17s 237ms/step - loss: 1.4413 - binary_accuracy: 0.8420 - precision: 0.8367 - recall: 0.8352 - val_loss: 1.8018 - val_binary_accuracy: 0.8160 - val_precision: 0.8322 - val_recall: 0.8158
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  inception_resnet_v2 (Functi  (None, 11, 11, 1536)     54336736
#  onal)
#
#  flatten (Flatten)           (None, 185856)            0
#
#  dense (Dense)               (None, 512)               95158784
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 149,496,033
# Trainable params: 149,435,489
# Non-trainable params: 60,544
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 101s 1s/step - loss: 0.7062 - binary_accuracy: 0.7482 - precision_1: 0.7443 - recall_1: 0.7278 - val_loss: 0.4232 - val_binary_accuracy: 0.8090 - val_precision_1: 0.7680 - val_recall_1: 0.9145
# Epoch 2/30
# 70/70 [==============================] - 61s 873ms/step - loss: 0.4101 - binary_accuracy: 0.8196 - precision_1: 0.8153 - recall_1: 0.8093 - val_loss: 0.2993 - val_binary_accuracy: 0.8715 - val_precision_1: 0.8758 - val_recall_1: 0.8816
# Epoch 3/30
# 70/70 [==============================] - 46s 655ms/step - loss: 0.4319 - binary_accuracy: 0.8661 - precision_1: 0.8470 - recall_1: 0.8815 - val_loss: 0.6531 - val_binary_accuracy: 0.8611 - val_precision_1: 0.9000 - val_recall_1: 0.8289
# Epoch 4/30
# 70/70 [==============================] - 70s 1s/step - loss: 0.3232 - binary_accuracy: 0.8625 - precision_1: 0.8614 - recall_1: 0.8519 - val_loss: 0.2480 - val_binary_accuracy: 0.8750 - val_precision_1: 0.9203 - val_recall_1: 0.8355
# Epoch 5/30
# 70/70 [==============================] - 73s 1s/step - loss: 0.2675 - binary_accuracy: 0.8938 - precision_1: 0.8862 - recall_1: 0.8944 - val_loss: 0.2382 - val_binary_accuracy: 0.8819 - val_precision_1: 0.8933 - val_recall_1: 0.8816
# Epoch 6/30
# 70/70 [==============================] - 46s 658ms/step - loss: 0.2174 - binary_accuracy: 0.9054 - precision_1: 0.9033 - recall_1: 0.9000 - val_loss: 0.2522 - val_binary_accuracy: 0.9028 - val_precision_1: 0.9026 - val_recall_1: 0.9145
# Epoch 7/30
# 70/70 [==============================] - 71s 1s/step - loss: 0.2252 - binary_accuracy: 0.9062 - precision_1: 0.8976 - recall_1: 0.9093 - val_loss: 0.2228 - val_binary_accuracy: 0.9028 - val_precision_1: 0.8974 - val_recall_1: 0.9211
# Epoch 8/30
# 70/70 [==============================] - 46s 651ms/step - loss: 0.2223 - binary_accuracy: 0.9098 - precision_1: 0.9072 - recall_1: 0.9056 - val_loss: 0.2868 - val_binary_accuracy: 0.9028 - val_precision_1: 0.9429 - val_recall_1: 0.8684
# Epoch 9/30
# 70/70 [==============================] - 45s 644ms/step - loss: 0.2047 - binary_accuracy: 0.9179 - precision_1: 0.9073 - recall_1: 0.9241 - val_loss: 0.2248 - val_binary_accuracy: 0.8993 - val_precision_1: 0.9128 - val_recall_1: 0.8947
# Epoch 10/30
# 70/70 [==============================] - 45s 643ms/step - loss: 0.1718 - binary_accuracy: 0.9277 - precision_1: 0.9258 - recall_1: 0.9241 - val_loss: 0.2665 - val_binary_accuracy: 0.9201 - val_precision_1: 0.9388 - val_recall_1: 0.9079
# Epoch 11/30
# 70/70 [==============================] - 45s 645ms/step - loss: 0.1551 - binary_accuracy: 0.9402 - precision_1: 0.9388 - recall_1: 0.9370 - val_loss: 0.2610 - val_binary_accuracy: 0.9167 - val_precision_1: 0.9000 - val_recall_1: 0.9474
# Epoch 12/30
# 70/70 [==============================] - 67s 966ms/step - loss: 0.1614 - binary_accuracy: 0.9402 - precision_1: 0.9308 - recall_1: 0.9463 - val_loss: 0.1925 - val_binary_accuracy: 0.9132 - val_precision_1: 0.8994 - val_recall_1: 0.9408
# Epoch 13/30
# 70/70 [==============================] - 46s 657ms/step - loss: 0.1288 - binary_accuracy: 0.9482 - precision_1: 0.9398 - recall_1: 0.9537 - val_loss: 0.2176 - val_binary_accuracy: 0.8958 - val_precision_1: 0.8720 - val_recall_1: 0.9408
# Epoch 14/30
# 70/70 [==============================] - 68s 981ms/step - loss: 0.1323 - binary_accuracy: 0.9545 - precision_1: 0.9519 - recall_1: 0.9537 - val_loss: 0.1788 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9527 - val_recall_1: 0.9276
# Epoch 15/30
# 70/70 [==============================] - 46s 656ms/step - loss: 0.1227 - binary_accuracy: 0.9527 - precision_1: 0.9419 - recall_1: 0.9611 - val_loss: 0.1976 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9404 - val_recall_1: 0.9342
# Epoch 16/30
# 70/70 [==============================] - 45s 644ms/step - loss: 0.0949 - binary_accuracy: 0.9652 - precision_1: 0.9630 - recall_1: 0.9648 - val_loss: 0.2673 - val_binary_accuracy: 0.9201 - val_precision_1: 0.9108 - val_recall_1: 0.9408
# Epoch 17/30
# 70/70 [==============================] - 45s 643ms/step - loss: 0.0936 - binary_accuracy: 0.9625 - precision_1: 0.9594 - recall_1: 0.9630 - val_loss: 0.3152 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9592 - val_recall_1: 0.9276
# Epoch 18/30
# 70/70 [==============================] - 45s 644ms/step - loss: 0.0790 - binary_accuracy: 0.9723 - precision_1: 0.9704 - recall_1: 0.9722 - val_loss: 0.3119 - val_binary_accuracy: 0.9444 - val_precision_1: 0.9595 - val_recall_1: 0.9342
# Epoch 19/30
# 70/70 [==============================] - 45s 643ms/step - loss: 0.0752 - binary_accuracy: 0.9741 - precision_1: 0.9740 - recall_1: 0.9722 - val_loss: 0.2842 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9295 - val_recall_1: 0.9539
# Epoch 20/30
# 70/70 [==============================] - 45s 644ms/step - loss: 0.0792 - binary_accuracy: 0.9750 - precision_1: 0.9723 - recall_1: 0.9759 - val_loss: 0.3430 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9589 - val_recall_1: 0.9211
# Epoch 21/30
# 70/70 [==============================] - 45s 644ms/step - loss: 0.0720 - binary_accuracy: 0.9732 - precision_1: 0.9688 - recall_1: 0.9759 - val_loss: 0.3901 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9718 - val_recall_1: 0.9079
# Epoch 22/30
# 70/70 [==============================] - 45s 643ms/step - loss: 0.0667 - binary_accuracy: 0.9786 - precision_1: 0.9778 - recall_1: 0.9778 - val_loss: 0.2993 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9720 - val_recall_1: 0.9145
# Epoch 23/30
# 70/70 [==============================] - 45s 643ms/step - loss: 0.0558 - binary_accuracy: 0.9839 - precision_1: 0.9798 - recall_1: 0.9870 - val_loss: 0.2950 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9728 - val_recall_1: 0.9408
# Epoch 24/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0403 - binary_accuracy: 0.9884 - precision_1: 0.9871 - recall_1: 0.9889Restoring model weights from the end of the best epoch: 14.
# 70/70 [==============================] - 46s 652ms/step - loss: 0.0403 - binary_accuracy: 0.9884 - precision_1: 0.9871 - recall_1: 0.9889 - val_loss: 0.3028 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9728 - val_recall_1: 0.9408
# Epoch 00024: early stopping
# fold 4 f1: 0.9382716049382717

# %% [markdown]
# ## Plot ROC (after training run)

# %%
f1s
# Out:
# [0.8994082840236686,
#  0.9261363636363638,
#  0.9485094850948509,
#  0.9405405405405406,
#  0.9382716049382717]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="ROC Curve (" +notebook_iteration + ")",
)
ax.legend(loc="lower right")
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[0, 0.2],
    ylim=[0.8, 1],
    title= "ROC Curve (" +notebook_iteration + ")" + " (zoomed in at top left)",
)
ax.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Plot ROC (from saved models)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)


y_preds = []
y_tests = []
tprs = []
aucs = []
f1s = []
mean_fpr = np.linspace(0, 1, 100)

for fold in range(num_splits):
  test_ds = full_ds.shard(num_splits, index=fold)
  x_test, y_test = [], []
  for images, labels in test_ds.unbatch():
    x_test.append(images.numpy())
    y_test.append(labels.numpy())
  x_test = np.array(x_test)
  y_test = np.array(y_test)

  load_path = Path( model_dir / str(fold) / "final_network.h5" )
  model = keras.models.load_model( load_path)
  print(f"Loading {Path(load_path)}")

  # test predictions and calculate test metrics
  y_pred = model.predict(x_test).ravel().round().astype(int)
  y_preds.append(y_pred)
  y_tests.append(y_test)

  fpr, tpr, thresholds = roc_curve(y_test, y_pred)
  interp_tpr = np.interp(mean_fpr, fpr, tpr)
  interp_tpr[0] = 0.0
  tprs.append(interp_tpr)
  aucs.append(roc_auc_score(y_test, y_pred))
  f1s.append(f1_score(y_test, y_pred, average="binary"))

  print(f"fold {fold} f1: {f1_score(y_test, y_pred, average='binary')}")
  print(f1s)

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="ROC Curve (" +notebook_iteration + ")",
)
ax.legend(loc="lower right")
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[0, 0.2],
    ylim=[0.8, 1],
    title= "ROC Curve (" +notebook_iteration + ")" + " (zoomed in at top left)",
)
ax.legend(loc="lower right")
plt.show()
# Out:
# Found 1751 files belonging to 2 classes.
# Loading /content/drive/MyDrive/OTH/space-eye/models/i10a/0/final_network.h5
# fold 0 f1: 0.896969696969697
# [0.896969696969697]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i10a/1/final_network.h5
# fold 1 f1: 0.9455587392550143
# [0.896969696969697, 0.9455587392550143]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i10a/2/final_network.h5
# fold 2 f1: 0.9380530973451328
# [0.896969696969697, 0.9455587392550143, 0.9380530973451328]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i10a/3/final_network.h5
# fold 3 f1: 0.9408450704225352
# [0.896969696969697, 0.9455587392550143, 0.9380530973451328, 0.9408450704225352]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i10a/4/final_network.h5
# fold 4 f1: 0.9387755102040817
# [0.896969696969697, 0.9455587392550143, 0.9380530973451328, 0.9408450704225352, 0.9387755102040817]

# %% [markdown]
# ## Tune

# %% [markdown]
# informative only, not set up to change model parameters automatically

# %%
# !pip install -q keras-tuner

# %%
import keras_tuner as kt
import numpy as np

tf.keras.backend.clear_session()  # clear the previous runs
batch_size = 128
epochs = 5

#set up dataset
full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)

val_ds = full_ds.shard(10, index=0)

train_ds = full_ds.take(0)
for i in range(1, 10):
  train_ds = full_ds.concatenate(full_ds.shard(10, index=i))

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(tuner_dir / 'tuned_network.h5', save_best_only=True, monitor='recall', mode='max')
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)

tuner = kt.BayesianOptimization(hypermodel=build_model_tuner, objective='recall', max_trials=5)
print(tuner.search_space_summary(extended=True))

tuner.search(train_ds, epochs=epochs, validation_data=val_ds, callbacks=[checkpoint_cb, early_stopping_cb], verbose=2)

print(tuner.results_summary())
