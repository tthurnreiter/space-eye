# %%
notebook_iteration = "i11"

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
# !nvidia-smi -L

#avoid running into GPU OOM errors because TF greedily allocates all GPU memory
# for the first training run and doesn't release it, so no more memory is available for 
# the second.
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-38e42f15-e66a-6e62-18cb-98ae9dc822cb)
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Set configs

# %%
from pathlib import Path

#data_dir = Path("/content/drive/MyDrive/OTH/space-eye/dataset/flattened_cropped")
base_dir = Path("/content/drive/MyDrive/OTH/space-eye")
data_dir = Path("/content/drive/MyDrive/OTH/space-eye/dataset/jpg600")
model_dir =  base_dir / "models" / notebook_iteration
log_dir = base_dir / "logs" / notebook_iteration
tuner_dir = base_dir / "tuner" / notebook_iteration
img_height = 400
img_width = 400
batch_size = 16
num_splits = 5 # for k-fold crossvalidation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f28c46612d31> in <module>()
#       4 base_dir = Path("/content/drive/MyDrive/OTH/space-eye")
#       5 data_dir = Path("/content/drive/MyDrive/OTH/space-eye/dataset/jpg600")
# ----> 6 model_dir =  base_dir / "models" / notebook_iteration
#       7 log_dir = base_dir / "logs" / notebook_iteration
#       8 tuner_dir = base_dir / "tuner" / notebook_iteration
#
# NameError: name 'notebook_iteration' is not defined

# %% [markdown]
# ## Copy data to local runtime

# %%
# !mkdir /dataset
# !cp -r $data_dir/* /dataset
data_dir = Path("/dataset")

# %%
nonships_count = len(list(data_dir.glob('nonships/*')))
ships_count = len(list(data_dir.glob('ships/*')))

ships_count, nonships_count
# Out:
# (871, 880)

# %% [markdown]
# ## Load Data

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import pandas as pd
from pathlib import Path
import os

# load metadata
nonships_meta = pd.read_csv(Path("/content/drive/MyDrive/OTH/space-eye/dataset/nonshipsAIS_2017_Zone17.csv"), index_col=None)
ships_meta = pd.read_csv(Path("/content/drive/MyDrive/OTH/space-eye/dataset/shipsAIS_2017_Zone17.csv"), index_col=None)

# remove duplicate entries from csv data
nonships_meta = nonships_meta.drop_duplicates(subset="newindex")
ships_meta = ships_meta.drop_duplicates(subset="newindex")

# find image files
data = []
classifiers = os.listdir(data_dir)
for classifier in classifiers:
  classifier_dir = os.path.join(data_dir, classifier)
  for item in sorted(os.listdir(classifier_dir)):
    filename = os.path.join(classifier, item)
    number = Path(filename).stem.split("_")[-1]
    data.append([str(filename), str(classifier), int(number)])

image_data = pd.DataFrame(data, columns=['filename', 'class', 'number'])

#merge data
ships_meta["class"] = "ships"
ships_meta.rename(columns={"newindex" : "number"}, inplace=True)
nonships_meta["class"] = "nonships"
nonships_meta.rename(columns={"newindex" : "number"}, inplace=True)

df_data = image_data
df_data = pd.merge(df_data, ships_meta, how='left', on=["number", "class"])
df_data = pd.merge(df_data, nonships_meta, how='left', on=["number", "class"])

df_data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                             filename  ...                                         envelope_y
# 0            ships/ships_image_0.jpg  ...                                                NaN
# 1            ships/ships_image_1.jpg  ...                                                NaN
# 2           ships/ships_image_10.jpg  ...                                                NaN
# 3          ships/ships_image_100.jpg  ...                                                NaN
# 4          ships/ships_image_101.jpg  ...                                                NaN
# ...                              ...  ...                                                ...
# 1746  nonships/nonships_image_95.jpg  ...  POLYGON ((-79.98891429114776 26.34658744768258...
# 1747  nonships/nonships_image_96.jpg  ...  POLYGON ((-79.96215555981016 26.47006574369414...
# 1748  nonships/nonships_image_97.jpg  ...  POLYGON ((-79.96756047140948 26.68008743099022...
# 1749  nonships/nonships_image_98.jpg  ...  POLYGON ((-79.97636915029581 26.68351465628567...
# 1750  nonships/nonships_image_99.jpg  ...  POLYGON ((-80.03769046501085 25.7212426966049,...
#
# [1751 rows x 25 columns]

# %% [markdown]
# ### Display some loaded images

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

viz_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)

plt.figure(figsize=(15, 15))
for images, labels in viz_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f46dd5fa8170> in <module>()
#       3
#       4 viz_ds = tf.keras.preprocessing.image_dataset_from_directory(
# ----> 5     data_dir,
#       6     seed=1337,
#       7     image_size=(img_width, img_height),
#
# NameError: name 'data_dir' is not defined

# %% [markdown]
# ## Set up and visualize Data Augmentation

# %%
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
    ]
)

plt.figure(figsize=(10, 10))
for images, _ in viz_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2d2909840534> in <module>()
#      11
#      12 plt.figure(figsize=(10, 10))
# ---> 13 for images, _ in viz_ds.take(4):
#      14     for i in range(9):
#      15         augmented_images = data_augmentation(images)
#
# NameError: name 'viz_ds' is not defined

# %% [markdown]
# ## Define Model

# %%
from tensorflow import keras
import keras.backend as K

def build_model_tuner(hp):
  learning_rate = hp.Float('learning_rate', 1e-04, 0.01, sampling='log')
  model = build_model()
  #lr_schedule1 = optimizers.schedules.ExponentialDecay(initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9)
  
  model.compile(
      optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
      loss='binary_crossentropy',
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  return model

def build_model():
  base_model = keras.applications.EfficientNetB4(
      weights="imagenet",  # Load weights pre-trained on ImageNet.
      include_top=False, # Do not include the ImageNet classifier at the top.
      input_shape=(img_width, img_height, 3),
  )  

  # Freeze the base_model
  base_model.trainable = False

  # Create new model on top
  inputs = keras.Input(shape=(img_width, img_height, 3))
  x = inputs
  x = data_augmentation(inputs)  # Apply random data augmentation

  # EfficientNetB7 needs no prescaling
  # # Pre-trained NASNetLarge weights requires that input be scaled
  # # from (0, 255) to a range of (-1., +1.), the rescaling layer
  # # outputs: `(inputs * scale) + offset`
  # scale_layer = keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
  # x = scale_layer(x)


  # The base model contains batchnorm layers. We want to keep them in inference mode
  # when we unfreeze the base model for fine-tuning, so we make sure that the
  # base_model is running in inference mode here.
  x = base_model(x, training=False)
  x = keras.layers.GlobalAveragePooling2D()(x)
  x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
  outputs = keras.layers.Dense(1, activation='sigmoid')(x)
  model = keras.Model(inputs, outputs)
  model.summary()
  
  return model

from tensorflow.keras import layers

def make_model(input_shape, num_classes):
  inputs = keras.Input(shape=input_shape)
  # Image augmentation block
  x = data_augmentation(inputs)
  x = inputs

  # Entry block
  x = layers.Rescaling(1.0 / 255)(x)
  x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  x = layers.Conv2D(64, 3, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  previous_block_activation = x  # Set aside residual

  for size in [128, 256, 512, 728]:
      x = layers.Activation("relu")(x)
      x = layers.SeparableConv2D(size, 3, padding="same")(x)
      x = layers.BatchNormalization()(x)

      x = layers.Activation("relu")(x)
      x = layers.SeparableConv2D(size, 3, padding="same")(x)
      x = layers.BatchNormalization()(x)

      x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

      # Project residual
      residual = layers.Conv2D(size, 1, strides=2, padding="same")(
          previous_block_activation
      )
      x = layers.add([x, residual])  # Add back residual
      previous_block_activation = x  # Set aside next residual

  x = layers.SeparableConv2D(1024, 3, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  x = layers.GlobalAveragePooling2D()(x)
  if num_classes == 2:
      activation = "sigmoid"
      units = 1
  else:
      activation = "softmax"
      units = num_classes

  x = layers.Dropout(0.5)(x)
  outputs = layers.Dense(units, activation=activation)(x)
  model = keras.Model(inputs, outputs)
  model.summary()
  return model

# %% [markdown]
# ## Train

# %%
# # displays tensorboard within the notebook
# %load_ext tensorboard
# %tensorboard --logdir $log_dir

# %%
import tensorflow as tf
from tensorflow.keras import metrics, optimizers
from sklearn.model_selection import KFold
from sklearn.metrics import roc_curve, roc_auc_score, auc, f1_score
import numpy as np
import time

tensorboard_dir = log_dir / "tensorboard" / time.strftime('%d_%m_%y-%H_%M')

#variables that hold our test results across runs
y_preds = []
y_tests = []
tprs = []
aucs = []
f1s = []
mean_fpr = np.linspace(0, 1, 100)

#set up dataset
full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)

for fold in range(num_splits):
  print("FOLD " + str(fold))
  
  #setup k-fold crossvalidations
  test_ds = full_ds.shard(num_splits, index=fold)
 
  fold_ds = full_ds.take(0)
  for i in range(num_splits):
    if i!=fold:
      fold_ds = fold_ds.concatenate(full_ds.shard(num_splits, index=i))
  
  fold_ds = fold_ds.shuffle(1000)
  
  num_in_fold = np.ceil((ships_count+nonships_count)*(1-1/num_splits)/batch_size)
  num_train = int(num_in_fold*0.8)
  num_val = num_in_fold - num_train
  
  train_ds = fold_ds.take(num_train)
  val_ds = fold_ds.skip(num_train).take(num_val)
  
  #improves performance
  AUTOTUNE = tf.data.AUTOTUNE
  train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
  
  # #Freeze the base model and only train the extra layer
  model = build_model()
  #model = make_model(input_shape=(img_width, img_height) + (3,), num_classes=2)

  lr_schedule1 = optimizers.schedules.ExponentialDecay(initial_learning_rate=0.01, decay_steps=25, decay_rate=0.8)
  
  model.compile(
      optimizer=optimizers.Adam(learning_rate=lr_schedule1),
      loss='binary_crossentropy',
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  tensorboard1_cb = tf.keras.callbacks.TensorBoard(tensorboard_dir / str(fold) / "a")
  checkpoint1_cb = tf.keras.callbacks.ModelCheckpoint(model_dir / str(fold) / "a" / "checkpoint_network.h5", monitor='val_loss', save_best_only=True)
  early_stopping1_cb = tf.keras.callbacks.EarlyStopping(patience=5, verbose=1, monitor='val_loss', restore_best_weights=True)
  callbacks1 = [checkpoint1_cb, tensorboard1_cb, early_stopping1_cb]
  
  model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=callbacks1)

  # Unfreeze the top 20 layers and finetune model with low learning rate
  for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True
  model.summary()

  lr_schedule2 = optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-4, decay_steps=100, decay_rate=0.9)

  model.compile(
      optimizer=keras.optimizers.Adam(learning_rate=lr_schedule2),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  tensorboard2_cb = tf.keras.callbacks.TensorBoard(tensorboard_dir / str(fold) / "b")
  checkpoint2_cb = tf.keras.callbacks.ModelCheckpoint(model_dir / str(fold) / "b" / "checkpoint_network.h5", monitor='val_loss', save_best_only=True)
  early_stopping2_cb = tf.keras.callbacks.EarlyStopping(patience=10, verbose=1, monitor='val_loss', restore_best_weights=True)
  callbacks2 = [checkpoint2_cb, tensorboard2_cb, early_stopping2_cb]

  model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=callbacks2)

  model.save(model_dir / str(fold) / "final_network.h5")
  
  # extract data from sharded test dataset again (this is a pain)
  # otherwise, the labels were mismatched with the images for some reason
  x_test, y_test = [], []
  for images, labels in test_ds.unbatch():
    x_test.append(images.numpy())
    y_test.append(labels.numpy())
  x_test = np.array(x_test)
  y_test = np.array(y_test)

  # test predictions and calculate test metrics
  y_pred = model.predict(x_test).ravel().round().astype(int)
  y_preds.append(y_pred)
  y_tests.append(y_test)

  fpr, tpr, thresholds = roc_curve(y_test, y_pred)
  interp_tpr = np.interp(mean_fpr, fpr, tpr)
  interp_tpr[0] = 0.0
  tprs.append(interp_tpr)
  aucs.append(roc_auc_score(y_test, y_pred))
  f1s.append(f1_score(y_test, y_pred, average="binary"))

  print(f"fold {fold} f1: {f1_score(y_test, y_pred, average='binary')}")

  tf.keras.backend.clear_session()
# Out:
# Found 1751 files belonging to 2 classes.
# FOLD 0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71688192/71686520 [==============================] - 1s 0us/step
# 71696384/71686520 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 1,793
# Non-trainable params: 17,673,823
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/30
# 70/70 [==============================] - 64s 438ms/step - loss: 0.5176 - binary_accuracy: 0.7375 - precision: 0.7446 - recall: 0.7009 - val_loss: 0.4928 - val_binary_accuracy: 0.7396 - val_precision: 0.7500 - val_recall: 0.7347
# Epoch 2/30
# 70/70 [==============================] - 14s 208ms/step - loss: 0.4292 - binary_accuracy: 0.7946 - precision: 0.8046 - recall: 0.7633 - val_loss: 0.4718 - val_binary_accuracy: 0.7743 - val_precision: 0.8060 - val_recall: 0.7347
# Epoch 3/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.4044 - binary_accuracy: 0.8134 - precision: 0.8231 - recall: 0.7853 - val_loss: 0.4741 - val_binary_accuracy: 0.7639 - val_precision: 0.7516 - val_recall: 0.8027
# Epoch 4/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4069 - binary_accuracy: 0.8143 - precision: 0.8234 - recall: 0.7872 - val_loss: 0.4678 - val_binary_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7619
# Epoch 5/30
# 70/70 [==============================] - 15s 210ms/step - loss: 0.3905 - binary_accuracy: 0.8304 - precision: 0.8381 - recall: 0.8073 - val_loss: 0.4671 - val_binary_accuracy: 0.7812 - val_precision: 0.8000 - val_recall: 0.7619
# Epoch 6/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3864 - binary_accuracy: 0.8357 - precision: 0.8519 - recall: 0.8018 - val_loss: 0.4680 - val_binary_accuracy: 0.7812 - val_precision: 0.7958 - val_recall: 0.7687
# Epoch 7/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3807 - binary_accuracy: 0.8402 - precision: 0.8506 - recall: 0.8147 - val_loss: 0.4673 - val_binary_accuracy: 0.7743 - val_precision: 0.7971 - val_recall: 0.7483
# Epoch 8/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3814 - binary_accuracy: 0.8304 - precision: 0.8330 - recall: 0.8147 - val_loss: 0.4673 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 9/30
# 70/70 [==============================] - 13s 182ms/step - loss: 0.3967 - binary_accuracy: 0.8152 - precision: 0.8225 - recall: 0.7908 - val_loss: 0.4671 - val_binary_accuracy: 0.7778 - val_precision: 0.8029 - val_recall: 0.7483
# Epoch 10/30
# 70/70 [==============================] - 15s 210ms/step - loss: 0.3771 - binary_accuracy: 0.8339 - precision: 0.8459 - recall: 0.8055 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 11/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3787 - binary_accuracy: 0.8357 - precision: 0.8425 - recall: 0.8147 - val_loss: 0.4671 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 12/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3772 - binary_accuracy: 0.8330 - precision: 0.8377 - recall: 0.8147 - val_loss: 0.4671 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 13/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.3838 - binary_accuracy: 0.8348 - precision: 0.8488 - recall: 0.8037 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 14/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3916 - binary_accuracy: 0.8277 - precision: 0.8333 - recall: 0.8073 - val_loss: 0.4671 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 15/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.3883 - binary_accuracy: 0.8232 - precision: 0.8330 - recall: 0.7963 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 16/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.3914 - binary_accuracy: 0.8304 - precision: 0.8420 - recall: 0.8018 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 17/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.3896 - binary_accuracy: 0.8313 - precision: 0.8477 - recall: 0.7963 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 18/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.3761 - binary_accuracy: 0.8366 - precision: 0.8441 - recall: 0.8147 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 19/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.3805 - binary_accuracy: 0.8304 - precision: 0.8447 - recall: 0.7982 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 20/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.3909 - binary_accuracy: 0.8268 - precision: 0.8318 - recall: 0.8073 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 21/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.3807 - binary_accuracy: 0.8295 - precision: 0.8484 - recall: 0.7908 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 22/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3832 - binary_accuracy: 0.8321 - precision: 0.8362 - recall: 0.8147 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 23/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.3860 - binary_accuracy: 0.8339 - precision: 0.8419 - recall: 0.8110 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 24/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3862 - binary_accuracy: 0.8268 - precision: 0.8318 - recall: 0.8073 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 25/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.3807 - binary_accuracy: 0.8241 - precision: 0.8346 - recall: 0.7963 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 26/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.3892 - binary_accuracy: 0.8286 - precision: 0.8324 - recall: 0.8110 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 27/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.3924 - binary_accuracy: 0.8259 - precision: 0.8391 - recall: 0.7945 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 28/30
# 70/70 [==============================] - ETA: 0s - loss: 0.3923 - binary_accuracy: 0.8348 - precision: 0.8448 - recall: 0.8092Restoring model weights from the end of the best epoch: 23.
# 70/70 [==============================] - 13s 184ms/step - loss: 0.3923 - binary_accuracy: 0.8348 - precision: 0.8448 - recall: 0.8092 - val_loss: 0.4670 - val_binary_accuracy: 0.7708 - val_precision: 0.8000 - val_recall: 0.7347
# Epoch 00028: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 17,550,409
# Non-trainable params: 125,207
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 92s 1s/step - loss: 0.3656 - binary_accuracy: 0.8571 - precision_1: 0.8571 - recall_1: 0.8477 - val_loss: 0.3889 - val_binary_accuracy: 0.8542 - val_precision_1: 0.8621 - val_recall_1: 0.8503
# Epoch 2/30
# 70/70 [==============================] - 69s 985ms/step - loss: 0.2199 - binary_accuracy: 0.9116 - precision_1: 0.9130 - recall_1: 0.9046 - val_loss: 0.2939 - val_binary_accuracy: 0.8889 - val_precision_1: 0.9021 - val_recall_1: 0.8776
# Epoch 3/30
# 70/70 [==============================] - 69s 986ms/step - loss: 0.1478 - binary_accuracy: 0.9402 - precision_1: 0.9426 - recall_1: 0.9339 - val_loss: 0.2791 - val_binary_accuracy: 0.8889 - val_precision_1: 0.8912 - val_recall_1: 0.8912
# Epoch 4/30
# 70/70 [==============================] - 69s 981ms/step - loss: 0.1219 - binary_accuracy: 0.9518 - precision_1: 0.9505 - recall_1: 0.9505 - val_loss: 0.2486 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9638 - val_recall_1: 0.9048
# Epoch 5/30
# 70/70 [==============================] - 65s 929ms/step - loss: 0.1079 - binary_accuracy: 0.9589 - precision_1: 0.9612 - recall_1: 0.9541 - val_loss: 0.2591 - val_binary_accuracy: 0.9271 - val_precision_1: 0.9632 - val_recall_1: 0.8912
# Epoch 6/30
# 70/70 [==============================] - 65s 927ms/step - loss: 0.0688 - binary_accuracy: 0.9741 - precision_1: 0.9760 - recall_1: 0.9706 - val_loss: 0.2628 - val_binary_accuracy: 0.9271 - val_precision_1: 0.9500 - val_recall_1: 0.9048
# Epoch 7/30
# 70/70 [==============================] - 65s 927ms/step - loss: 0.1055 - binary_accuracy: 0.9563 - precision_1: 0.9576 - recall_1: 0.9523 - val_loss: 0.2708 - val_binary_accuracy: 0.9201 - val_precision_1: 0.9627 - val_recall_1: 0.8776
# Epoch 8/30
# 70/70 [==============================] - 65s 924ms/step - loss: 0.0692 - binary_accuracy: 0.9795 - precision_1: 0.9780 - recall_1: 0.9798 - val_loss: 0.3126 - val_binary_accuracy: 0.9444 - val_precision_1: 0.9645 - val_recall_1: 0.9252
# Epoch 9/30
# 70/70 [==============================] - 65s 924ms/step - loss: 0.0469 - binary_accuracy: 0.9848 - precision_1: 0.9818 - recall_1: 0.9872 - val_loss: 0.3248 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9779 - val_recall_1: 0.9048
# Epoch 10/30
# 70/70 [==============================] - 65s 926ms/step - loss: 0.0269 - binary_accuracy: 0.9920 - precision_1: 0.9963 - recall_1: 0.9872 - val_loss: 0.4075 - val_binary_accuracy: 0.9306 - val_precision_1: 0.9262 - val_recall_1: 0.9388
# Epoch 11/30
# 70/70 [==============================] - 65s 924ms/step - loss: 0.0389 - binary_accuracy: 0.9857 - precision_1: 0.9835 - recall_1: 0.9872 - val_loss: 0.3317 - val_binary_accuracy: 0.9479 - val_precision_1: 0.9648 - val_recall_1: 0.9320
# Epoch 12/30
# 70/70 [==============================] - 65s 923ms/step - loss: 0.0271 - binary_accuracy: 0.9902 - precision_1: 0.9890 - recall_1: 0.9908 - val_loss: 0.3317 - val_binary_accuracy: 0.9479 - val_precision_1: 0.9783 - val_recall_1: 0.9184
# Epoch 13/30
# 70/70 [==============================] - 65s 926ms/step - loss: 0.0302 - binary_accuracy: 0.9884 - precision_1: 0.9890 - recall_1: 0.9872 - val_loss: 0.3564 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9848 - val_recall_1: 0.8844
# Epoch 14/30
# 70/70 [==============================] - 68s 973ms/step - loss: 0.0243 - binary_accuracy: 0.9911 - precision_1: 0.9945 - recall_1: 0.9872 - val_loss: 0.2474 - val_binary_accuracy: 0.9479 - val_precision_1: 0.9783 - val_recall_1: 0.9184
# Epoch 15/30
# 70/70 [==============================] - 65s 931ms/step - loss: 0.0101 - binary_accuracy: 0.9964 - precision_1: 0.9982 - recall_1: 0.9945 - val_loss: 0.3110 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9926 - val_recall_1: 0.9184
# Epoch 16/30
# 70/70 [==============================] - 65s 930ms/step - loss: 0.0038 - binary_accuracy: 0.9991 - precision_1: 1.0000 - recall_1: 0.9982 - val_loss: 0.3206 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9926 - val_recall_1: 0.9184
# Epoch 17/30
# 70/70 [==============================] - 65s 926ms/step - loss: 0.0010 - binary_accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 0.3451 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9855 - val_recall_1: 0.9252
# Epoch 18/30
# 70/70 [==============================] - 65s 928ms/step - loss: 0.0019 - binary_accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 0.3632 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9855 - val_recall_1: 0.9252
# Epoch 19/30
# 70/70 [==============================] - 65s 926ms/step - loss: 9.0400e-04 - binary_accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 0.3344 - val_binary_accuracy: 0.9514 - val_precision_1: 0.9784 - val_recall_1: 0.9252
# Epoch 20/30
# 70/70 [==============================] - 65s 928ms/step - loss: 0.0014 - binary_accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000 - val_loss: 0.3936 - val_binary_accuracy: 0.9583 - val_precision_1: 0.9927 - val_recall_1: 0.9252
# Epoch 21/30
# 70/70 [==============================] - 65s 922ms/step - loss: 0.0046 - binary_accuracy: 0.9991 - precision_1: 1.0000 - recall_1: 0.9982 - val_loss: 0.3192 - val_binary_accuracy: 0.9514 - val_precision_1: 0.9716 - val_recall_1: 0.9320
# Epoch 22/30
# 70/70 [==============================] - 64s 921ms/step - loss: 0.0128 - binary_accuracy: 0.9982 - precision_1: 0.9982 - recall_1: 0.9982 - val_loss: 0.3262 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9926 - val_recall_1: 0.9184
# Epoch 23/30
# 70/70 [==============================] - 65s 925ms/step - loss: 0.0055 - binary_accuracy: 0.9982 - precision_1: 0.9982 - recall_1: 0.9982 - val_loss: 0.3309 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9855 - val_recall_1: 0.9252
# Epoch 24/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0076 - binary_accuracy: 0.9973 - precision_1: 0.9982 - recall_1: 0.9963Restoring model weights from the end of the best epoch: 14.
# 70/70 [==============================] - 65s 930ms/step - loss: 0.0076 - binary_accuracy: 0.9973 - precision_1: 0.9982 - recall_1: 0.9963 - val_loss: 0.3064 - val_binary_accuracy: 0.9549 - val_precision_1: 0.9926 - val_recall_1: 0.9184
# Epoch 00024: early stopping
# fold 0 f1: 0.9442815249266864
# FOLD 1
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 1,793
# Non-trainable params: 17,673,823
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/30
# 70/70 [==============================] - 54s 432ms/step - loss: 0.5077 - binary_accuracy: 0.7291 - precision: 0.7355 - recall: 0.7101 - val_loss: 0.4786 - val_binary_accuracy: 0.7604 - val_precision: 0.8378 - val_recall: 0.6458
# Epoch 2/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.4469 - binary_accuracy: 0.7786 - precision: 0.7954 - recall: 0.7464 - val_loss: 0.4565 - val_binary_accuracy: 0.7778 - val_precision: 0.8226 - val_recall: 0.7083
# Epoch 3/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.4424 - binary_accuracy: 0.7849 - precision: 0.7947 - recall: 0.7645 - val_loss: 0.4536 - val_binary_accuracy: 0.7812 - val_precision: 0.8347 - val_recall: 0.7014
# Epoch 4/30
# 70/70 [==============================] - 14s 204ms/step - loss: 0.4256 - binary_accuracy: 0.8020 - precision: 0.8217 - recall: 0.7681 - val_loss: 0.4463 - val_binary_accuracy: 0.7882 - val_precision: 0.7862 - val_recall: 0.7917
# Epoch 5/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4107 - binary_accuracy: 0.8056 - precision: 0.8347 - recall: 0.7591 - val_loss: 0.4457 - val_binary_accuracy: 0.7951 - val_precision: 0.7972 - val_recall: 0.7917
# Epoch 6/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.3993 - binary_accuracy: 0.8137 - precision: 0.8402 - recall: 0.7717 - val_loss: 0.4421 - val_binary_accuracy: 0.7847 - val_precision: 0.8060 - val_recall: 0.7500
# Epoch 7/30
# 70/70 [==============================] - 14s 204ms/step - loss: 0.4021 - binary_accuracy: 0.8092 - precision: 0.8307 - recall: 0.7736 - val_loss: 0.4417 - val_binary_accuracy: 0.7882 - val_precision: 0.8168 - val_recall: 0.7431
# Epoch 8/30
# 70/70 [==============================] - 14s 204ms/step - loss: 0.4084 - binary_accuracy: 0.8146 - precision: 0.8327 - recall: 0.7844 - val_loss: 0.4416 - val_binary_accuracy: 0.7847 - val_precision: 0.8154 - val_recall: 0.7361
# Epoch 9/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.4117 - binary_accuracy: 0.8119 - precision: 0.8356 - recall: 0.7736 - val_loss: 0.4416 - val_binary_accuracy: 0.7847 - val_precision: 0.8154 - val_recall: 0.7361
# Epoch 10/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.4000 - binary_accuracy: 0.8155 - precision: 0.8409 - recall: 0.7754 - val_loss: 0.4416 - val_binary_accuracy: 0.7847 - val_precision: 0.8154 - val_recall: 0.7361
# Epoch 11/30
# 70/70 [==============================] - 12s 179ms/step - loss: 0.4076 - binary_accuracy: 0.8128 - precision: 0.8373 - recall: 0.7736 - val_loss: 0.4416 - val_binary_accuracy: 0.7847 - val_precision: 0.8154 - val_recall: 0.7361
# Epoch 12/30
# 70/70 [==============================] - 13s 179ms/step - loss: 0.4083 - binary_accuracy: 0.8092 - precision: 0.8282 - recall: 0.7772 - val_loss: 0.4416 - val_binary_accuracy: 0.7847 - val_precision: 0.8154 - val_recall: 0.7361
# Epoch 13/30
# 70/70 [==============================] - 12s 179ms/step - loss: 0.4039 - binary_accuracy: 0.8119 - precision: 0.8451 - recall: 0.7609 - val_loss: 0.4416 - val_binary_accuracy: 0.7847 - val_precision: 0.8154 - val_recall: 0.7361
# Epoch 14/30
# 70/70 [==============================] - ETA: 0s - loss: 0.4019 - binary_accuracy: 0.8137 - precision: 0.8443 - recall: 0.7663Restoring model weights from the end of the best epoch: 9.
# 70/70 [==============================] - 13s 182ms/step - loss: 0.4019 - binary_accuracy: 0.8137 - precision: 0.8443 - recall: 0.7663 - val_loss: 0.4416 - val_binary_accuracy: 0.7847 - val_precision: 0.8154 - val_recall: 0.7361
# Epoch 00014: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 17,550,409
# Non-trainable params: 125,207
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 90s 1s/step - loss: 0.3770 - binary_accuracy: 0.8380 - precision_1: 0.8536 - recall_1: 0.8134 - val_loss: 0.3188 - val_binary_accuracy: 0.8854 - val_precision_1: 0.9111 - val_recall_1: 0.8542
# Epoch 2/30
# 70/70 [==============================] - 68s 967ms/step - loss: 0.2400 - binary_accuracy: 0.9082 - precision_1: 0.9136 - recall_1: 0.9004 - val_loss: 0.2279 - val_binary_accuracy: 0.8993 - val_precision_1: 0.9457 - val_recall_1: 0.8472
# Epoch 3/30
# 70/70 [==============================] - 68s 977ms/step - loss: 0.1800 - binary_accuracy: 0.9280 - precision_1: 0.9354 - recall_1: 0.9185 - val_loss: 0.2012 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9252 - val_recall_1: 0.9444
# Epoch 4/30
# 70/70 [==============================] - 68s 977ms/step - loss: 0.1252 - binary_accuracy: 0.9559 - precision_1: 0.9683 - recall_1: 0.9420 - val_loss: 0.1737 - val_binary_accuracy: 0.9306 - val_precision_1: 0.9366 - val_recall_1: 0.9236
# Epoch 5/30
# 70/70 [==============================] - 68s 976ms/step - loss: 0.1183 - binary_accuracy: 0.9568 - precision_1: 0.9582 - recall_1: 0.9547 - val_loss: 0.1668 - val_binary_accuracy: 0.9444 - val_precision_1: 0.9324 - val_recall_1: 0.9583
# Epoch 6/30
# 70/70 [==============================] - 64s 916ms/step - loss: 0.0855 - binary_accuracy: 0.9649 - precision_1: 0.9689 - recall_1: 0.9601 - val_loss: 0.1833 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9500 - val_recall_1: 0.9236
# Epoch 7/30
# 70/70 [==============================] - 68s 970ms/step - loss: 0.0850 - binary_accuracy: 0.9667 - precision_1: 0.9707 - recall_1: 0.9620 - val_loss: 0.1545 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9371 - val_recall_1: 0.9306
# Epoch 8/30
# 70/70 [==============================] - 65s 923ms/step - loss: 0.0598 - binary_accuracy: 0.9739 - precision_1: 0.9712 - recall_1: 0.9764 - val_loss: 0.1795 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9562 - val_recall_1: 0.9097
# Epoch 9/30
# 70/70 [==============================] - 64s 915ms/step - loss: 0.0568 - binary_accuracy: 0.9775 - precision_1: 0.9800 - recall_1: 0.9746 - val_loss: 0.2451 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9145 - val_recall_1: 0.9653
# Epoch 10/30
# 70/70 [==============================] - 64s 912ms/step - loss: 0.0482 - binary_accuracy: 0.9802 - precision_1: 0.9836 - recall_1: 0.9764 - val_loss: 0.2194 - val_binary_accuracy: 0.9271 - val_precision_1: 0.9424 - val_recall_1: 0.9097
# Epoch 11/30
# 70/70 [==============================] - 65s 927ms/step - loss: 0.0471 - binary_accuracy: 0.9775 - precision_1: 0.9782 - recall_1: 0.9764 - val_loss: 0.2017 - val_binary_accuracy: 0.9236 - val_precision_1: 0.9485 - val_recall_1: 0.8958
# Epoch 12/30
# 70/70 [==============================] - 65s 922ms/step - loss: 0.0553 - binary_accuracy: 0.9820 - precision_1: 0.9819 - recall_1: 0.9819 - val_loss: 0.2356 - val_binary_accuracy: 0.9271 - val_precision_1: 0.9424 - val_recall_1: 0.9097
# Epoch 13/30
# 70/70 [==============================] - 64s 920ms/step - loss: 0.0472 - binary_accuracy: 0.9802 - precision_1: 0.9783 - recall_1: 0.9819 - val_loss: 0.2279 - val_binary_accuracy: 0.9271 - val_precision_1: 0.9624 - val_recall_1: 0.8889
# Epoch 14/30
# 70/70 [==============================] - 64s 921ms/step - loss: 0.0396 - binary_accuracy: 0.9838 - precision_1: 0.9819 - recall_1: 0.9855 - val_loss: 0.2720 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9496 - val_recall_1: 0.9167
# Epoch 15/30
# 70/70 [==============================] - 64s 918ms/step - loss: 0.0253 - binary_accuracy: 0.9919 - precision_1: 0.9892 - recall_1: 0.9946 - val_loss: 0.2703 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9437 - val_recall_1: 0.9306
# Epoch 16/30
# 70/70 [==============================] - 65s 927ms/step - loss: 0.0241 - binary_accuracy: 0.9874 - precision_1: 0.9838 - recall_1: 0.9909 - val_loss: 0.2797 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9504 - val_recall_1: 0.9306
# Epoch 17/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0271 - binary_accuracy: 0.9883 - precision_1: 0.9873 - recall_1: 0.9891Restoring model weights from the end of the best epoch: 7.
# 70/70 [==============================] - 65s 928ms/step - loss: 0.0271 - binary_accuracy: 0.9883 - precision_1: 0.9873 - recall_1: 0.9891 - val_loss: 0.2990 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9441 - val_recall_1: 0.9375
# Epoch 00017: early stopping
# fold 1 f1: 0.9139465875370919
# FOLD 2
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 1,793
# Non-trainable params: 17,673,823
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/30
# 70/70 [==============================] - 53s 419ms/step - loss: 0.5552 - binary_accuracy: 0.7264 - precision: 0.7427 - recall: 0.6919 - val_loss: 0.4744 - val_binary_accuracy: 0.7563 - val_precision: 0.8378 - val_recall: 0.6503
# Epoch 2/30
# 70/70 [==============================] - 14s 203ms/step - loss: 0.4623 - binary_accuracy: 0.7705 - precision: 0.7918 - recall: 0.7333 - val_loss: 0.4506 - val_binary_accuracy: 0.7814 - val_precision: 0.8596 - val_recall: 0.6853
# Epoch 3/30
# 70/70 [==============================] - 14s 202ms/step - loss: 0.4434 - binary_accuracy: 0.7885 - precision: 0.8089 - recall: 0.7550 - val_loss: 0.4334 - val_binary_accuracy: 0.7814 - val_precision: 0.8361 - val_recall: 0.7133
# Epoch 4/30
# 70/70 [==============================] - 14s 203ms/step - loss: 0.4290 - binary_accuracy: 0.7975 - precision: 0.8185 - recall: 0.7640 - val_loss: 0.4300 - val_binary_accuracy: 0.7778 - val_precision: 0.8293 - val_recall: 0.7133
# Epoch 5/30
# 70/70 [==============================] - 12s 178ms/step - loss: 0.4262 - binary_accuracy: 0.8092 - precision: 0.8343 - recall: 0.7712 - val_loss: 0.4307 - val_binary_accuracy: 0.7814 - val_precision: 0.8417 - val_recall: 0.7063
# Epoch 6/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4189 - binary_accuracy: 0.8056 - precision: 0.8304 - recall: 0.7676 - val_loss: 0.4292 - val_binary_accuracy: 0.7742 - val_precision: 0.8279 - val_recall: 0.7063
# Epoch 7/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.4171 - binary_accuracy: 0.8110 - precision: 0.8311 - recall: 0.7802 - val_loss: 0.4270 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 8/30
# 70/70 [==============================] - 14s 204ms/step - loss: 0.4089 - binary_accuracy: 0.8155 - precision: 0.8327 - recall: 0.7892 - val_loss: 0.4261 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 9/30
# 70/70 [==============================] - 14s 203ms/step - loss: 0.4215 - binary_accuracy: 0.8074 - precision: 0.8298 - recall: 0.7730 - val_loss: 0.4258 - val_binary_accuracy: 0.7849 - val_precision: 0.8320 - val_recall: 0.7273
# Epoch 10/30
# 70/70 [==============================] - 12s 178ms/step - loss: 0.4205 - binary_accuracy: 0.8101 - precision: 0.8221 - recall: 0.7910 - val_loss: 0.4258 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 11/30
# 70/70 [==============================] - 12s 178ms/step - loss: 0.4041 - binary_accuracy: 0.8191 - precision: 0.8498 - recall: 0.7748 - val_loss: 0.4258 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 12/30
# 70/70 [==============================] - 14s 203ms/step - loss: 0.4078 - binary_accuracy: 0.8074 - precision: 0.8337 - recall: 0.7676 - val_loss: 0.4258 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 13/30
# 70/70 [==============================] - 12s 178ms/step - loss: 0.4041 - binary_accuracy: 0.8263 - precision: 0.8481 - recall: 0.7946 - val_loss: 0.4258 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 14/30
# 70/70 [==============================] - 12s 178ms/step - loss: 0.4136 - binary_accuracy: 0.8164 - precision: 0.8268 - recall: 0.8000 - val_loss: 0.4258 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 15/30
# 70/70 [==============================] - 12s 178ms/step - loss: 0.4212 - binary_accuracy: 0.8029 - precision: 0.8231 - recall: 0.7712 - val_loss: 0.4258 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 16/30
# 70/70 [==============================] - 12s 178ms/step - loss: 0.4127 - binary_accuracy: 0.8137 - precision: 0.8359 - recall: 0.7802 - val_loss: 0.4258 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 17/30
# 70/70 [==============================] - ETA: 0s - loss: 0.4215 - binary_accuracy: 0.8047 - precision: 0.8288 - recall: 0.7676Restoring model weights from the end of the best epoch: 12.
# 70/70 [==============================] - 13s 181ms/step - loss: 0.4215 - binary_accuracy: 0.8047 - precision: 0.8288 - recall: 0.7676 - val_loss: 0.4258 - val_binary_accuracy: 0.7814 - val_precision: 0.8306 - val_recall: 0.7203
# Epoch 00017: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 17,550,409
# Non-trainable params: 125,207
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 90s 1s/step - loss: 0.4173 - binary_accuracy: 0.8272 - precision_1: 0.8484 - recall_1: 0.7964 - val_loss: 0.3161 - val_binary_accuracy: 0.8674 - val_precision_1: 0.9141 - val_recall_1: 0.8182
# Epoch 2/30
# 70/70 [==============================] - 68s 974ms/step - loss: 0.2502 - binary_accuracy: 0.9001 - precision_1: 0.9007 - recall_1: 0.8991 - val_loss: 0.2926 - val_binary_accuracy: 0.8853 - val_precision_1: 0.9440 - val_recall_1: 0.8252
# Epoch 3/30
# 70/70 [==============================] - 68s 973ms/step - loss: 0.1630 - binary_accuracy: 0.9361 - precision_1: 0.9449 - recall_1: 0.9261 - val_loss: 0.2632 - val_binary_accuracy: 0.8996 - val_precision_1: 0.9323 - val_recall_1: 0.8671
# Epoch 4/30
# 70/70 [==============================] - 64s 919ms/step - loss: 0.1251 - binary_accuracy: 0.9460 - precision_1: 0.9541 - recall_1: 0.9369 - val_loss: 0.3541 - val_binary_accuracy: 0.8925 - val_precision_1: 0.9449 - val_recall_1: 0.8392
# Epoch 5/30
# 70/70 [==============================] - 65s 922ms/step - loss: 0.1096 - binary_accuracy: 0.9550 - precision_1: 0.9583 - recall_1: 0.9514 - val_loss: 0.3158 - val_binary_accuracy: 0.9032 - val_precision_1: 0.9531 - val_recall_1: 0.8531
# Epoch 6/30
# 70/70 [==============================] - 68s 970ms/step - loss: 0.1035 - binary_accuracy: 0.9613 - precision_1: 0.9689 - recall_1: 0.9532 - val_loss: 0.2613 - val_binary_accuracy: 0.9140 - val_precision_1: 0.9760 - val_recall_1: 0.8531
# Epoch 7/30
# 70/70 [==============================] - 64s 915ms/step - loss: 0.0765 - binary_accuracy: 0.9694 - precision_1: 0.9728 - recall_1: 0.9658 - val_loss: 0.3301 - val_binary_accuracy: 0.9104 - val_precision_1: 0.9538 - val_recall_1: 0.8671
# Epoch 8/30
# 70/70 [==============================] - 64s 917ms/step - loss: 0.0653 - binary_accuracy: 0.9721 - precision_1: 0.9764 - recall_1: 0.9676 - val_loss: 0.2915 - val_binary_accuracy: 0.9283 - val_precision_1: 0.9624 - val_recall_1: 0.8951
# Epoch 9/30
# 70/70 [==============================] - 64s 917ms/step - loss: 0.0548 - binary_accuracy: 0.9721 - precision_1: 0.9746 - recall_1: 0.9694 - val_loss: 0.3497 - val_binary_accuracy: 0.9211 - val_precision_1: 0.9690 - val_recall_1: 0.8741
# Epoch 10/30
# 70/70 [==============================] - 64s 920ms/step - loss: 0.0450 - binary_accuracy: 0.9820 - precision_1: 0.9872 - recall_1: 0.9766 - val_loss: 0.3710 - val_binary_accuracy: 0.9391 - val_precision_1: 0.9437 - val_recall_1: 0.9371
# Epoch 11/30
# 70/70 [==============================] - 64s 914ms/step - loss: 0.0447 - binary_accuracy: 0.9811 - precision_1: 0.9837 - recall_1: 0.9784 - val_loss: 0.2929 - val_binary_accuracy: 0.9462 - val_precision_1: 0.9571 - val_recall_1: 0.9371
# Epoch 12/30
# 70/70 [==============================] - 68s 970ms/step - loss: 0.0389 - binary_accuracy: 0.9865 - precision_1: 0.9909 - recall_1: 0.9820 - val_loss: 0.2585 - val_binary_accuracy: 0.9427 - val_precision_1: 0.9379 - val_recall_1: 0.9510
# Epoch 13/30
# 70/70 [==============================] - 64s 921ms/step - loss: 0.0277 - binary_accuracy: 0.9883 - precision_1: 0.9909 - recall_1: 0.9856 - val_loss: 0.2703 - val_binary_accuracy: 0.9391 - val_precision_1: 0.9500 - val_recall_1: 0.9301
# Epoch 14/30
# 70/70 [==============================] - 64s 920ms/step - loss: 0.0100 - binary_accuracy: 0.9982 - precision_1: 0.9982 - recall_1: 0.9982 - val_loss: 0.3210 - val_binary_accuracy: 0.9391 - val_precision_1: 0.9375 - val_recall_1: 0.9441
# Epoch 15/30
# 70/70 [==============================] - 64s 918ms/step - loss: 0.0130 - binary_accuracy: 0.9946 - precision_1: 0.9928 - recall_1: 0.9964 - val_loss: 0.3452 - val_binary_accuracy: 0.9355 - val_precision_1: 0.9562 - val_recall_1: 0.9161
# Epoch 16/30
# 70/70 [==============================] - 64s 919ms/step - loss: 0.0079 - binary_accuracy: 0.9973 - precision_1: 0.9982 - recall_1: 0.9964 - val_loss: 0.3419 - val_binary_accuracy: 0.9391 - val_precision_1: 0.9500 - val_recall_1: 0.9301
# Epoch 17/30
# 70/70 [==============================] - 64s 916ms/step - loss: 0.0040 - binary_accuracy: 0.9991 - precision_1: 0.9982 - recall_1: 1.0000 - val_loss: 0.3541 - val_binary_accuracy: 0.9391 - val_precision_1: 0.9565 - val_recall_1: 0.9231
# Epoch 18/30
# 70/70 [==============================] - 64s 919ms/step - loss: 0.0048 - binary_accuracy: 0.9982 - precision_1: 0.9982 - recall_1: 0.9982 - val_loss: 0.3574 - val_binary_accuracy: 0.9462 - val_precision_1: 0.9571 - val_recall_1: 0.9371
# Epoch 19/30
# 70/70 [==============================] - 65s 923ms/step - loss: 0.0055 - binary_accuracy: 0.9982 - precision_1: 0.9982 - recall_1: 0.9982 - val_loss: 0.3329 - val_binary_accuracy: 0.9534 - val_precision_1: 0.9452 - val_recall_1: 0.9650
# Epoch 20/30
# 70/70 [==============================] - 64s 916ms/step - loss: 0.0053 - binary_accuracy: 0.9991 - precision_1: 1.0000 - recall_1: 0.9982 - val_loss: 0.3565 - val_binary_accuracy: 0.9498 - val_precision_1: 0.9329 - val_recall_1: 0.9720
# Epoch 21/30
# 70/70 [==============================] - 64s 917ms/step - loss: 0.0084 - binary_accuracy: 0.9964 - precision_1: 0.9964 - recall_1: 0.9964 - val_loss: 0.3265 - val_binary_accuracy: 0.9534 - val_precision_1: 0.9452 - val_recall_1: 0.9650
# Epoch 22/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0139 - binary_accuracy: 0.9928 - precision_1: 0.9946 - recall_1: 0.9910Restoring model weights from the end of the best epoch: 12.
# 70/70 [==============================] - 65s 924ms/step - loss: 0.0139 - binary_accuracy: 0.9928 - precision_1: 0.9946 - recall_1: 0.9910 - val_loss: 0.2844 - val_binary_accuracy: 0.9606 - val_precision_1: 0.9583 - val_recall_1: 0.9650
# Epoch 00022: early stopping
# fold 2 f1: 0.9459459459459459
# FOLD 3
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 1,793
# Non-trainable params: 17,673,823
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/30
# 70/70 [==============================] - 60s 516ms/step - loss: 0.5070 - binary_accuracy: 0.7420 - precision: 0.7545 - recall: 0.7347 - val_loss: 0.4041 - val_binary_accuracy: 0.7986 - val_precision: 0.8065 - val_recall: 0.7463
# Epoch 2/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.4460 - binary_accuracy: 0.7893 - precision: 0.8115 - recall: 0.7661 - val_loss: 0.4107 - val_binary_accuracy: 0.8194 - val_precision: 0.7887 - val_recall: 0.8358
# Epoch 3/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4158 - binary_accuracy: 0.7991 - precision: 0.8308 - recall: 0.7627 - val_loss: 0.3991 - val_binary_accuracy: 0.8403 - val_precision: 0.8333 - val_recall: 0.8209
# Epoch 4/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4084 - binary_accuracy: 0.8161 - precision: 0.8367 - recall: 0.7958 - val_loss: 0.3874 - val_binary_accuracy: 0.8125 - val_precision: 0.8333 - val_recall: 0.7463
# Epoch 5/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.3909 - binary_accuracy: 0.8250 - precision: 0.8459 - recall: 0.8045 - val_loss: 0.3833 - val_binary_accuracy: 0.8333 - val_precision: 0.8525 - val_recall: 0.7761
# Epoch 6/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.3786 - binary_accuracy: 0.8366 - precision: 0.8545 - recall: 0.8202 - val_loss: 0.3816 - val_binary_accuracy: 0.8333 - val_precision: 0.8525 - val_recall: 0.7761
# Epoch 7/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.3952 - binary_accuracy: 0.8170 - precision: 0.8407 - recall: 0.7923 - val_loss: 0.3804 - val_binary_accuracy: 0.8229 - val_precision: 0.8547 - val_recall: 0.7463
# Epoch 8/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.3912 - binary_accuracy: 0.8170 - precision: 0.8382 - recall: 0.7958 - val_loss: 0.3801 - val_binary_accuracy: 0.8368 - val_precision: 0.8537 - val_recall: 0.7836
# Epoch 9/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.3819 - binary_accuracy: 0.8313 - precision: 0.8453 - recall: 0.8202 - val_loss: 0.3799 - val_binary_accuracy: 0.8368 - val_precision: 0.8595 - val_recall: 0.7761
# Epoch 10/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.3818 - binary_accuracy: 0.8357 - precision: 0.8543 - recall: 0.8185 - val_loss: 0.3796 - val_binary_accuracy: 0.8368 - val_precision: 0.8595 - val_recall: 0.7761
# Epoch 11/30
# 70/70 [==============================] - 13s 181ms/step - loss: 0.3975 - binary_accuracy: 0.8134 - precision: 0.8285 - recall: 0.8010 - val_loss: 0.3797 - val_binary_accuracy: 0.8368 - val_precision: 0.8595 - val_recall: 0.7761
# Epoch 12/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.3793 - binary_accuracy: 0.8286 - precision: 0.8470 - recall: 0.8115 - val_loss: 0.3797 - val_binary_accuracy: 0.8368 - val_precision: 0.8595 - val_recall: 0.7761
# Epoch 13/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.3770 - binary_accuracy: 0.8357 - precision: 0.8595 - recall: 0.8115 - val_loss: 0.3797 - val_binary_accuracy: 0.8368 - val_precision: 0.8595 - val_recall: 0.7761
# Epoch 14/30
# 70/70 [==============================] - 13s 180ms/step - loss: 0.3899 - binary_accuracy: 0.8277 - precision: 0.8467 - recall: 0.8098 - val_loss: 0.3797 - val_binary_accuracy: 0.8368 - val_precision: 0.8595 - val_recall: 0.7761
# Epoch 15/30
# 70/70 [==============================] - ETA: 0s - loss: 0.3853 - binary_accuracy: 0.8375 - precision: 0.8654 - recall: 0.8080Restoring model weights from the end of the best epoch: 10.
# 70/70 [==============================] - 13s 184ms/step - loss: 0.3853 - binary_accuracy: 0.8375 - precision: 0.8654 - recall: 0.8080 - val_loss: 0.3797 - val_binary_accuracy: 0.8368 - val_precision: 0.8595 - val_recall: 0.7761
# Epoch 00015: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 17,550,409
# Non-trainable params: 125,207
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 90s 1s/step - loss: 0.3765 - binary_accuracy: 0.8455 - precision_1: 0.8636 - recall_1: 0.8290 - val_loss: 0.2918 - val_binary_accuracy: 0.8924 - val_precision_1: 0.9055 - val_recall_1: 0.8582
# Epoch 2/30
# 70/70 [==============================] - 69s 987ms/step - loss: 0.2542 - binary_accuracy: 0.8902 - precision_1: 0.9004 - recall_1: 0.8831 - val_loss: 0.2596 - val_binary_accuracy: 0.9062 - val_precision_1: 0.9084 - val_recall_1: 0.8881
# Epoch 3/30
# 70/70 [==============================] - 65s 936ms/step - loss: 0.1743 - binary_accuracy: 0.9196 - precision_1: 0.9320 - recall_1: 0.9092 - val_loss: 0.2743 - val_binary_accuracy: 0.9028 - val_precision_1: 0.8786 - val_recall_1: 0.9179
# Epoch 4/30
# 70/70 [==============================] - 65s 933ms/step - loss: 0.1400 - binary_accuracy: 0.9429 - precision_1: 0.9411 - recall_1: 0.9476 - val_loss: 0.3188 - val_binary_accuracy: 0.9167 - val_precision_1: 0.8873 - val_recall_1: 0.9403
# Epoch 5/30
# 70/70 [==============================] - 69s 992ms/step - loss: 0.1249 - binary_accuracy: 0.9491 - precision_1: 0.9558 - recall_1: 0.9442 - val_loss: 0.2250 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9265 - val_recall_1: 0.9403
# Epoch 6/30
# ...
# Epoch 14/30
# 70/70 [==============================] - 65s 934ms/step - loss: 0.0109 - binary_accuracy: 0.9973 - precision_1: 0.9948 - recall_1: 1.0000 - val_loss: 0.2114 - val_binary_accuracy: 0.9618 - val_precision_1: 0.9624 - val_recall_1: 0.9552
# Epoch 15/30
# 70/70 [==============================] - 65s 928ms/step - loss: 0.0125 - binary_accuracy: 0.9955 - precision_1: 0.9965 - recall_1: 0.9948 - val_loss: 0.2326 - val_binary_accuracy: 0.9583 - val_precision_1: 0.9485 - val_recall_1: 0.9627
# Epoch 16/30
# 70/70 [==============================] - 65s 935ms/step - loss: 0.0174 - binary_accuracy: 0.9920 - precision_1: 0.9913 - recall_1: 0.9930 - val_loss: 0.2978 - val_binary_accuracy: 0.9583 - val_precision_1: 0.9485 - val_recall_1: 0.9627
# Epoch 17/30
# 70/70 [==============================] - 65s 930ms/step - loss: 0.0235 - binary_accuracy: 0.9937 - precision_1: 0.9930 - recall_1: 0.9948 - val_loss: 0.1934 - val_binary_accuracy: 0.9514 - val_precision_1: 0.9545 - val_recall_1: 0.9403
# Epoch 18/30
# 70/70 [==============================] - 64s 916ms/step - loss: 0.0153 - binary_accuracy: 0.9937 - precision_1: 0.9930 - recall_1: 0.9948 - val_loss: 0.2229 - val_binary_accuracy: 0.9479 - val_precision_1: 0.9343 - val_recall_1: 0.9552
# Epoch 19/30
# 70/70 [==============================] - 65s 935ms/step - loss: 0.0049 - binary_accuracy: 0.9991 - precision_1: 0.9983 - recall_1: 1.0000 - val_loss: 0.2246 - val_binary_accuracy: 0.9583 - val_precision_1: 0.9552 - val_recall_1: 0.9552
# Epoch 20/30
# 70/70 [==============================] - 65s 927ms/step - loss: 0.0062 - binary_accuracy: 0.9982 - precision_1: 0.9983 - recall_1: 0.9983 - val_loss: 0.2371 - val_binary_accuracy: 0.9583 - val_precision_1: 0.9552 - val_recall_1: 0.9552
# Epoch 21/30
# 70/70 [==============================] - 65s 929ms/step - loss: 0.0061 - binary_accuracy: 0.9982 - precision_1: 0.9983 - recall_1: 0.9983 - val_loss: 0.2529 - val_binary_accuracy: 0.9583 - val_precision_1: 0.9552 - val_recall_1: 0.9552
# Epoch 22/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0109 - binary_accuracy: 0.9964 - precision_1: 0.9965 - recall_1: 0.9965Restoring model weights from the end of the best epoch: 12.
# 70/70 [==============================] - 65s 934ms/step - loss: 0.0109 - binary_accuracy: 0.9964 - precision_1: 0.9965 - recall_1: 0.9965 - val_loss: 0.2603 - val_binary_accuracy: 0.9583 - val_precision_1: 0.9552 - val_recall_1: 0.9552
# Epoch 00022: early stopping
# fold 3 f1: 0.952112676056338
# FOLD 4
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 1,793
# Non-trainable params: 17,673,823
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/30
# 70/70 [==============================] - 54s 421ms/step - loss: 0.5594 - binary_accuracy: 0.7116 - precision: 0.7130 - recall: 0.6962 - val_loss: 0.4349 - val_binary_accuracy: 0.7917 - val_precision: 0.7857 - val_recall: 0.7857
# Epoch 2/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.4687 - binary_accuracy: 0.7616 - precision: 0.7678 - recall: 0.7414 - val_loss: 0.4151 - val_binary_accuracy: 0.7882 - val_precision: 0.8376 - val_recall: 0.7000
# Epoch 3/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4424 - binary_accuracy: 0.7866 - precision: 0.7973 - recall: 0.7613 - val_loss: 0.4076 - val_binary_accuracy: 0.8229 - val_precision: 0.8201 - val_recall: 0.8143
# Epoch 4/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4285 - binary_accuracy: 0.7937 - precision: 0.7993 - recall: 0.7776 - val_loss: 0.4013 - val_binary_accuracy: 0.8090 - val_precision: 0.8295 - val_recall: 0.7643
# Epoch 5/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4241 - binary_accuracy: 0.7982 - precision: 0.8079 - recall: 0.7758 - val_loss: 0.3987 - val_binary_accuracy: 0.8229 - val_precision: 0.8739 - val_recall: 0.7429
# Epoch 6/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4285 - binary_accuracy: 0.7830 - precision: 0.7892 - recall: 0.7649 - val_loss: 0.3980 - val_binary_accuracy: 0.8194 - val_precision: 0.8729 - val_recall: 0.7357
# Epoch 7/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4332 - binary_accuracy: 0.7821 - precision: 0.7965 - recall: 0.7505 - val_loss: 0.3969 - val_binary_accuracy: 0.8194 - val_precision: 0.8607 - val_recall: 0.7500
# Epoch 8/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4171 - binary_accuracy: 0.8054 - precision: 0.8190 - recall: 0.7776 - val_loss: 0.3962 - val_binary_accuracy: 0.8160 - val_precision: 0.8537 - val_recall: 0.7500
# Epoch 9/30
# 70/70 [==============================] - 15s 216ms/step - loss: 0.4102 - binary_accuracy: 0.8214 - precision: 0.8388 - recall: 0.7902 - val_loss: 0.3958 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 10/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4100 - binary_accuracy: 0.8018 - precision: 0.8164 - recall: 0.7722 - val_loss: 0.3956 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 11/30
# 70/70 [==============================] - 14s 206ms/step - loss: 0.4164 - binary_accuracy: 0.8080 - precision: 0.8213 - recall: 0.7812 - val_loss: 0.3956 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 12/30
# 70/70 [==============================] - 14s 205ms/step - loss: 0.4216 - binary_accuracy: 0.8071 - precision: 0.8173 - recall: 0.7848 - val_loss: 0.3956 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 13/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4124 - binary_accuracy: 0.8134 - precision: 0.8282 - recall: 0.7848 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 14/30
# 70/70 [==============================] - 15s 208ms/step - loss: 0.4142 - binary_accuracy: 0.8098 - precision: 0.8244 - recall: 0.7812 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 15/30
# 70/70 [==============================] - 15s 208ms/step - loss: 0.4262 - binary_accuracy: 0.8000 - precision: 0.8052 - recall: 0.7848 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 16/30
# 70/70 [==============================] - 15s 208ms/step - loss: 0.4088 - binary_accuracy: 0.8027 - precision: 0.8168 - recall: 0.7740 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 17/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4148 - binary_accuracy: 0.8116 - precision: 0.8314 - recall: 0.7758 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 18/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4206 - binary_accuracy: 0.8080 - precision: 0.8213 - recall: 0.7812 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 19/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4080 - binary_accuracy: 0.8089 - precision: 0.8253 - recall: 0.7776 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 20/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4086 - binary_accuracy: 0.8107 - precision: 0.8260 - recall: 0.7812 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 21/30
# 70/70 [==============================] - 15s 209ms/step - loss: 0.4207 - binary_accuracy: 0.7955 - precision: 0.8140 - recall: 0.7595 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 22/30
# 70/70 [==============================] - 14s 207ms/step - loss: 0.4161 - binary_accuracy: 0.8089 - precision: 0.8204 - recall: 0.7848 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 23/30
# 70/70 [==============================] - 15s 208ms/step - loss: 0.4182 - binary_accuracy: 0.8009 - precision: 0.8125 - recall: 0.7758 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 24/30
# 70/70 [==============================] - 13s 182ms/step - loss: 0.4083 - binary_accuracy: 0.8062 - precision: 0.8170 - recall: 0.7830 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 25/30
# 70/70 [==============================] - 13s 182ms/step - loss: 0.4168 - binary_accuracy: 0.8027 - precision: 0.8120 - recall: 0.7812 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 26/30
# 70/70 [==============================] - 13s 182ms/step - loss: 0.4142 - binary_accuracy: 0.8089 - precision: 0.8291 - recall: 0.7722 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 27/30
# 70/70 [==============================] - 13s 182ms/step - loss: 0.4204 - binary_accuracy: 0.8000 - precision: 0.8157 - recall: 0.7685 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 28/30
# 70/70 [==============================] - ETA: 0s - loss: 0.4153 - binary_accuracy: 0.8134 - precision: 0.8233 - recall: 0.7920Restoring model weights from the end of the best epoch: 23.
# 70/70 [==============================] - 13s 186ms/step - loss: 0.4153 - binary_accuracy: 0.8134 - precision: 0.8233 - recall: 0.7920 - val_loss: 0.3955 - val_binary_accuracy: 0.8194 - val_precision: 0.8548 - val_recall: 0.7571
# Epoch 00028: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  efficientnetb4 (Functional)  (None, 13, 13, 1792)     17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1792)              0
#
#  dense (Dense)               (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 17,550,409
# Non-trainable params: 125,207
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 92s 1s/step - loss: 0.4239 - binary_accuracy: 0.7920 - precision_1: 0.8042 - recall_1: 0.7649 - val_loss: 0.2924 - val_binary_accuracy: 0.8958 - val_precision_1: 0.8767 - val_recall_1: 0.9143
# Epoch 2/30
# 70/70 [==============================] - 69s 982ms/step - loss: 0.2813 - binary_accuracy: 0.8777 - precision_1: 0.8810 - recall_1: 0.8698 - val_loss: 0.2792 - val_binary_accuracy: 0.9167 - val_precision_1: 0.8973 - val_recall_1: 0.9357
# Epoch 3/30
# 70/70 [==============================] - 69s 989ms/step - loss: 0.2224 - binary_accuracy: 0.9071 - precision_1: 0.9196 - recall_1: 0.8897 - val_loss: 0.2561 - val_binary_accuracy: 0.9132 - val_precision_1: 0.8808 - val_recall_1: 0.9500
# Epoch 4/30
# 70/70 [==============================] - 69s 989ms/step - loss: 0.1555 - binary_accuracy: 0.9375 - precision_1: 0.9448 - recall_1: 0.9277 - val_loss: 0.1648 - val_binary_accuracy: 0.9479 - val_precision_1: 0.9433 - val_recall_1: 0.9500
# Epoch 5/30
# 70/70 [==============================] - 65s 930ms/step - loss: 0.1141 - binary_accuracy: 0.9518 - precision_1: 0.9595 - recall_1: 0.9421 - val_loss: 0.2091 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9231 - val_recall_1: 0.9429
# Epoch 6/30
# 70/70 [==============================] - 65s 926ms/step - loss: 0.0840 - binary_accuracy: 0.9607 - precision_1: 0.9586 - recall_1: 0.9620 - val_loss: 0.1748 - val_binary_accuracy: 0.9271 - val_precision_1: 0.9407 - val_recall_1: 0.9071
# Epoch 7/30
# 70/70 [==============================] - 65s 929ms/step - loss: 0.0903 - binary_accuracy: 0.9723 - precision_1: 0.9728 - recall_1: 0.9711 - val_loss: 0.2167 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9357 - val_recall_1: 0.9357
# Epoch 8/30
# 70/70 [==============================] - 65s 924ms/step - loss: 0.0501 - binary_accuracy: 0.9848 - precision_1: 0.9873 - recall_1: 0.9819 - val_loss: 0.2565 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9420 - val_recall_1: 0.9286
# Epoch 9/30
# 70/70 [==============================] - 65s 927ms/step - loss: 0.0383 - binary_accuracy: 0.9848 - precision_1: 0.9873 - recall_1: 0.9819 - val_loss: 0.2248 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9301 - val_recall_1: 0.9500
# Epoch 10/30
# 70/70 [==============================] - 65s 931ms/step - loss: 0.0378 - binary_accuracy: 0.9866 - precision_1: 0.9873 - recall_1: 0.9855 - val_loss: 0.2687 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9184 - val_recall_1: 0.9643
# Epoch 11/30
# 70/70 [==============================] - 65s 928ms/step - loss: 0.0421 - binary_accuracy: 0.9848 - precision_1: 0.9838 - recall_1: 0.9855 - val_loss: 0.2597 - val_binary_accuracy: 0.9375 - val_precision_1: 0.9178 - val_recall_1: 0.9571
# Epoch 12/30
# 70/70 [==============================] - 65s 924ms/step - loss: 0.0140 - binary_accuracy: 0.9955 - precision_1: 1.0000 - recall_1: 0.9910 - val_loss: 0.3285 - val_binary_accuracy: 0.9340 - val_precision_1: 0.9007 - val_recall_1: 0.9714
# Epoch 13/30
# 70/70 [==============================] - 65s 932ms/step - loss: 0.0503 - binary_accuracy: 0.9839 - precision_1: 0.9837 - recall_1: 0.9837 - val_loss: 0.2052 - val_binary_accuracy: 0.9410 - val_precision_1: 0.9489 - val_recall_1: 0.9286
# Epoch 14/30
# 70/70 [==============================] - ETA: 0s - loss: 0.0184 - binary_accuracy: 0.9929 - precision_1: 0.9910 - recall_1: 0.9946Restoring model weights from the end of the best epoch: 4.
# 70/70 [==============================] - 65s 930ms/step - loss: 0.0184 - binary_accuracy: 0.9929 - precision_1: 0.9910 - recall_1: 0.9946 - val_loss: 0.1997 - val_binary_accuracy: 0.9583 - val_precision_1: 0.9507 - val_recall_1: 0.9643
# Epoch 00014: early stopping
# fold 4 f1: 0.9353846153846154

# %% [markdown]
# ## Plot ROC (after training run)

# %%
f1s
# Out:
# [0.9442815249266864,
#  0.9139465875370919,
#  0.9459459459459459,
#  0.952112676056338,
#  0.9353846153846154]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="ROC Curve (" +notebook_iteration + ")",
)
ax.legend(loc="lower right")
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[0, 0.2],
    ylim=[0.8, 1],
    title= "ROC Curve (" +notebook_iteration + ")" + " (zoomed in at top left)",
)
ax.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Plot ROC (from saved models)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)


y_preds = []
y_tests = []
tprs = []
aucs = []
f1s = []
mean_fpr = np.linspace(0, 1, 100)

for fold in range(num_splits):
  test_ds = full_ds.shard(num_splits, index=fold)
  x_test, y_test = [], []
  for images, labels in test_ds.unbatch():
    x_test.append(images.numpy())
    y_test.append(labels.numpy())
  x_test = np.array(x_test)
  y_test = np.array(y_test)

  load_path = Path( model_dir / str(fold) / "final_network.h5" )
  model = keras.models.load_model( load_path)
  print(f"Loading {Path(load_path)}")

  # test predictions and calculate test metrics
  y_pred = model.predict(x_test).ravel().round().astype(int)
  y_preds.append(y_pred)
  y_tests.append(y_test)

  fpr, tpr, thresholds = roc_curve(y_test, y_pred)
  interp_tpr = np.interp(mean_fpr, fpr, tpr)
  interp_tpr[0] = 0.0
  tprs.append(interp_tpr)
  aucs.append(roc_auc_score(y_test, y_pred))
  f1s.append(f1_score(y_test, y_pred, average="binary"))

  print(f"fold {fold} f1: {f1_score(y_test, y_pred, average='binary')}")
  print(f1s)

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="ROC Curve (" +notebook_iteration + ")",
)
ax.legend(loc="lower right")
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[0, 0.2],
    ylim=[0.8, 1],
    title= "ROC Curve (" +notebook_iteration + ")" + " (zoomed in at top left)",
)
ax.legend(loc="lower right")
plt.show()
# Out:
# Found 1751 files belonging to 2 classes.
# Loading /content/drive/MyDrive/OTH/space-eye/models/i11/0/final_network.h5
# fold 0 f1: 0.8942598187311177
# [0.8942598187311177]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i11/1/final_network.h5
# fold 1 f1: 0.8805031446540881
# [0.8942598187311177, 0.8805031446540881]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i11/2/final_network.h5
# fold 2 f1: 0.8869565217391304
# [0.8942598187311177, 0.8805031446540881, 0.8869565217391304]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i11/3/final_network.h5
# fold 3 f1: 0.8081841432225063
# [0.8942598187311177, 0.8805031446540881, 0.8869565217391304, 0.8081841432225063]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i11/4/final_network.h5
# fold 4 f1: 0.8319999999999999
# [0.8942598187311177, 0.8805031446540881, 0.8869565217391304, 0.8081841432225063, 0.8319999999999999]

# %% [markdown]
# ## Tune

# %% [markdown]
# informative only, not set up to change model parameters automatically

# %%
# !pip install -q keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 4.4 MB/s

# %%
import keras_tuner as kt
import numpy as np

tf.keras.backend.clear_session()  # clear the previous runs
batch_size = 128
epochs = 5

#set up dataset
full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)

val_ds = full_ds.shard(10, index=0)

train_ds = full_ds.take(0)
for i in range(1, 10):
  train_ds = full_ds.concatenate(full_ds.shard(10, index=i))

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(tuner_dir / 'tuned_network.h5', save_best_only=True, monitor='recall', mode='max')
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)

tuner = kt.BayesianOptimization(hypermodel=build_model_tuner, objective='recall', max_trials=5)
print(tuner.search_space_summary(extended=True))

tuner.search(train_ds, epochs=epochs, validation_data=val_ds, callbacks=[checkpoint_cb, early_stopping_cb], verbose=2)

print(tuner.results_summary())
# Out:
# Found 1751 files belonging to 2 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-31eee7e3da03> in <module>()
#      23 early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
#      24
# ---> 25 tuner = kt.BayesianOptimization(hypermodel=build_model_tuner, objective='recall', max_trials=5)
#      26 print(tuner.search_space_summary(extended=True))
#      27
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/tuners/bayesian.py in __init__(self, hypermodel, objective, max_trials, num_initial_points, alpha, beta, seed, hyperparameters, tune_new_entries, allow_new_entries, **kwargs)
#     409             hyperparameters=hyperparameters,
#     410             tune_new_entries=tune_new_entries,
# --> 411             allow_new_entries=allow_new_entries,
#     412         )
#     413         super(
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/tuners/bayesian.py in __init__(self, objective, max_trials, num_initial_points, alpha, beta, seed, hyperparameters, allow_new_entries, tune_new_entries)
#     173             tune_new_entries=tune_new_entries,
#     174             allow_new_entries=allow_new_entries,
# --> 175             seed=seed,
#     176         )
#     177         self.num_initial_points = num_initial_points
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/oracle.py in __init__(self, objective, max_trials, hyperparameters, allow_new_entries, tune_new_entries, seed)
#      68         seed=None,
#      69     ):
# ---> 70         self.objective = _format_objective(objective)
#      71         self.max_trials = max_trials
#      72         if not hyperparameters:
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/oracle.py in _format_objective(objective)
#     464             )
#     465             error_msg = error_msg.format(obj=objective)
# --> 466             raise ValueError(error_msg)
#     467         return Objective(name=objective, direction=direction)
#     468     else:
#
# ValueError: Could not infer optimization direction ("min" or "max") for unknown metric "recall". Please specify the objective  asa `keras_tuner.Objective`, for example `keras_tuner.Objective("recall", direction="min")`.
