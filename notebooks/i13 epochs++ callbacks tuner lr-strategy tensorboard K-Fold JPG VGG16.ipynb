# %%
notebook_iteration = "i13"

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
# !nvidia-smi -L

#avoid running into GPU OOM errors because TF greedily allocates all GPU memory
# for the first training run and doesn't release it, so no more memory is available for 
# the second.
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-30726a26-a344-da4c-d386-09920f31b090)
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Set configs

# %%
from pathlib import Path

#data_dir = Path("/content/drive/MyDrive/OTH/space-eye/dataset/flattened_cropped")
base_dir = Path("/content/drive/MyDrive/OTH/space-eye")
data_dir = Path("/content/drive/MyDrive/OTH/space-eye/dataset/jpg600")
model_dir =  base_dir / "models" / notebook_iteration
log_dir = base_dir / "logs" / notebook_iteration
tuner_dir = base_dir / "tuner" / notebook_iteration
img_height = 400
img_width = 400
batch_size = 16
num_splits = 5 # for k-fold crossvalidation

# %% [markdown]
# ## Copy data to local runtime

# %%
# !mkdir /dataset
# !cp -r $data_dir/* /dataset
data_dir = Path("/dataset")
# Out:
# mkdir: cannot create directory ‘/dataset’: File exists

# %%
nonships_count = len(list(data_dir.glob('nonships/*')))
ships_count = len(list(data_dir.glob('ships/*')))

ships_count, nonships_count
# Out:
# (871, 880)

# %% [markdown]
# ## Load Data

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import pandas as pd
from pathlib import Path
import os

# load metadata
nonships_meta = pd.read_csv(Path("/content/drive/MyDrive/OTH/space-eye/dataset/nonshipsAIS_2017_Zone17.csv"), index_col=None)
ships_meta = pd.read_csv(Path("/content/drive/MyDrive/OTH/space-eye/dataset/shipsAIS_2017_Zone17.csv"), index_col=None)

# remove duplicate entries from csv data
nonships_meta = nonships_meta.drop_duplicates(subset="newindex")
ships_meta = ships_meta.drop_duplicates(subset="newindex")

# find image files
data = []
classifiers = os.listdir(data_dir)
for classifier in classifiers:
  classifier_dir = os.path.join(data_dir, classifier)
  for item in sorted(os.listdir(classifier_dir)):
    filename = os.path.join(classifier, item)
    number = Path(filename).stem.split("_")[-1]
    data.append([str(filename), str(classifier), int(number)])

image_data = pd.DataFrame(data, columns=['filename', 'class', 'number'])

#merge data
ships_meta["class"] = "ships"
ships_meta.rename(columns={"newindex" : "number"}, inplace=True)
nonships_meta["class"] = "nonships"
nonships_meta.rename(columns={"newindex" : "number"}, inplace=True)

df_data = image_data
df_data = pd.merge(df_data, ships_meta, how='left', on=["number", "class"])
df_data = pd.merge(df_data, nonships_meta, how='left', on=["number", "class"])

df_data
# Out:
#                             filename  ...                                         envelope_y
# 0            ships/ships_image_0.jpg  ...                                                NaN
# 1            ships/ships_image_1.jpg  ...                                                NaN
# 2           ships/ships_image_10.jpg  ...                                                NaN
# 3          ships/ships_image_100.jpg  ...                                                NaN
# 4          ships/ships_image_101.jpg  ...                                                NaN
# ...                              ...  ...                                                ...
# 1746  nonships/nonships_image_95.jpg  ...  POLYGON ((-79.98891429114776 26.34658744768258...
# 1747  nonships/nonships_image_96.jpg  ...  POLYGON ((-79.96215555981016 26.47006574369414...
# 1748  nonships/nonships_image_97.jpg  ...  POLYGON ((-79.96756047140948 26.68008743099022...
# 1749  nonships/nonships_image_98.jpg  ...  POLYGON ((-79.97636915029581 26.68351465628567...
# 1750  nonships/nonships_image_99.jpg  ...  POLYGON ((-80.03769046501085 25.7212426966049,...
#
# [1751 rows x 25 columns]

# %% [markdown]
# ### Display some loaded images

# %%
import matplotlib.pyplot as plt
import tensorflow as tf

viz_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)

plt.figure(figsize=(15, 15))
for images, labels in viz_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
# Out:
# Found 1751 files belonging to 2 classes.

# %% [markdown]
# ## Set up and visualize Data Augmentation

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
    ]
)

plt.figure(figsize=(10, 10))
for images, _ in viz_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ## Define Model

# %%
from tensorflow import keras
import keras.backend as K

def build_model_tuner(hp):
  learning_rate = hp.Float('learning_rate', 1e-04, 0.01, sampling='log')
  model = build_model()
  #lr_schedule1 = optimizers.schedules.ExponentialDecay(initial_learning_rate=0.01, decay_steps=100, decay_rate=0.9)
  
  model.compile(
      optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
      loss='binary_crossentropy',
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  return model

def build_model():
  base_model = keras.applications.VGG16(
      weights="imagenet",  # Load weights pre-trained on ImageNet.
      include_top=False, # Do not include the ImageNet classifier at the top.
      input_shape=(img_width, img_height, 3),
  )  

  # Freeze the base_model
  base_model.trainable = False

  # Create new model on top
  inputs = keras.Input(shape=(img_width, img_height, 3))
  x = inputs
  x = data_augmentation(inputs)  # Apply random data augmentation

  # # Pre-trained NASNetLarge weights requires that input be scaled
  # # from (0, 255) to a range of (-1., +1.), the rescaling layer
  # # outputs: `(inputs * scale) + offset`
  # scale_layer = keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
  # x = scale_layer(x)
  # Preprocess input for VGG16
  x = tf.keras.layers.Lambda(tf.keras.applications.vgg16.preprocess_input)(x)



  # The base model contains batchnorm layers. We want to keep them in inference mode
  # when we unfreeze the base model for fine-tuning, so we make sure that the
  # base_model is running in inference mode here.
  x = base_model(x, training=False)
  x = keras.layers.GlobalAveragePooling2D()(x)
  x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
  outputs = keras.layers.Dense(1, activation='sigmoid')(x)
  model = keras.Model(inputs, outputs)
  model.summary()
  
  return model

from tensorflow.keras import layers

def make_model(input_shape, num_classes):
  inputs = keras.Input(shape=input_shape)
  # Image augmentation block
  x = data_augmentation(inputs)
  x = inputs

  # Entry block
  x = layers.Rescaling(1.0 / 255)(x)
  x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  x = layers.Conv2D(64, 3, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  previous_block_activation = x  # Set aside residual

  for size in [128, 256, 512, 728]:
      x = layers.Activation("relu")(x)
      x = layers.SeparableConv2D(size, 3, padding="same")(x)
      x = layers.BatchNormalization()(x)

      x = layers.Activation("relu")(x)
      x = layers.SeparableConv2D(size, 3, padding="same")(x)
      x = layers.BatchNormalization()(x)

      x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

      # Project residual
      residual = layers.Conv2D(size, 1, strides=2, padding="same")(
          previous_block_activation
      )
      x = layers.add([x, residual])  # Add back residual
      previous_block_activation = x  # Set aside next residual

  x = layers.SeparableConv2D(1024, 3, padding="same")(x)
  x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)

  x = layers.GlobalAveragePooling2D()(x)
  if num_classes == 2:
      activation = "sigmoid"
      units = 1
  else:
      activation = "softmax"
      units = num_classes

  x = layers.Dropout(0.5)(x)
  outputs = layers.Dense(units, activation=activation)(x)
  model = keras.Model(inputs, outputs)
  model.summary()
  return model

# %% [markdown]
# ## Train

# %%
# # displays tensorboard within the notebook
# %load_ext tensorboard
# %tensorboard --logdir $log_dir

# %%
import tensorflow as tf
from tensorflow.keras import metrics, optimizers
from sklearn.model_selection import KFold
from sklearn.metrics import roc_curve, roc_auc_score, auc, f1_score
import numpy as np
import time

tensorboard_dir = log_dir / "tensorboard" / time.strftime('%d_%m_%y-%H_%M')

#variables that hold our test results across runs
y_preds = []
y_tests = []
tprs = []
aucs = []
f1s = []
mean_fpr = np.linspace(0, 1, 100)

#set up dataset
full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)


for fold in range(num_splits):
  print("FOLD " + str(fold))
  
  #setup k-fold crossvalidations
  test_ds = full_ds.shard(num_splits, index=fold)
 
  fold_ds = full_ds.take(0)
  for i in range(num_splits):
    if i!=fold:
      fold_ds = fold_ds.concatenate(full_ds.shard(num_splits, index=i))
  
  fold_ds = fold_ds.shuffle(1000)
  
  num_in_fold = np.ceil((ships_count+nonships_count)*(1-1/num_splits)/batch_size)
  num_train = int(num_in_fold*0.8)
  num_val = num_in_fold - num_train
  
  train_ds = fold_ds.take(num_train)
  val_ds = fold_ds.skip(num_train).take(num_val)
  
  #improves performance
  AUTOTUNE = tf.data.AUTOTUNE
  train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
  
  # #Freeze the base model and only train the extra layer
  model = build_model()
  #model = make_model(input_shape=(img_width, img_height) + (3,), num_classes=2)

  lr_schedule1 = optimizers.schedules.ExponentialDecay(initial_learning_rate=0.01, decay_steps=25, decay_rate=0.8)
  
  model.compile(
      optimizer=optimizers.Adam(learning_rate=lr_schedule1),
      loss='binary_crossentropy',
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  tensorboard1_cb = tf.keras.callbacks.TensorBoard(tensorboard_dir / str(fold) / "a")
  checkpoint1_cb = tf.keras.callbacks.ModelCheckpoint(model_dir / str(fold) / "a" / "checkpoint_network.h5", monitor='val_loss', save_best_only=True)
  early_stopping1_cb = tf.keras.callbacks.EarlyStopping(patience=5, verbose=1, monitor='val_loss', restore_best_weights=True)
  callbacks1 = [checkpoint1_cb, tensorboard1_cb, early_stopping1_cb]
  
  model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=callbacks1)

  # Unfreeze the top 4 layers and finetune model with low learning rate
  for layer in model.layers[-3:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True
  model.summary()

  lr_schedule2 = optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-4, decay_steps=100, decay_rate=0.9)

  model.compile(
      optimizer=keras.optimizers.Adam(learning_rate=lr_schedule2),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=[tf.keras.metrics.BinaryAccuracy(), tf.keras.metrics.Precision(), tf.keras.metrics.Recall()],
  )

  tensorboard2_cb = tf.keras.callbacks.TensorBoard(tensorboard_dir / str(fold) / "b")
  checkpoint2_cb = tf.keras.callbacks.ModelCheckpoint(model_dir / str(fold) / "b" / "checkpoint_network.h5", monitor='val_loss', save_best_only=True)
  early_stopping2_cb = tf.keras.callbacks.EarlyStopping(patience=10, verbose=1, monitor='val_loss', restore_best_weights=True)
  callbacks2 = [checkpoint2_cb, tensorboard2_cb, early_stopping2_cb]

  model.fit(train_ds, epochs=30, validation_data=val_ds, callbacks=callbacks2)

  model.save(model_dir / str(fold) / "final_network.h5")
  
  # extract data from sharded test dataset again (this is a pain)
  # otherwise, the labels were mismatched with the images for some reason
  x_test, y_test = [], []
  for images, labels in test_ds.unbatch():
    x_test.append(images.numpy())
    y_test.append(labels.numpy())
  x_test = np.array(x_test)
  y_test = np.array(y_test)

  # test predictions and calculate test metrics
  y_pred = model.predict(x_test).ravel().round().astype(int)
  y_preds.append(y_pred)
  y_tests.append(y_test)

  fpr, tpr, thresholds = roc_curve(y_test, y_pred)
  interp_tpr = np.interp(mean_fpr, fpr, tpr)
  interp_tpr[0] = 0.0
  tprs.append(interp_tpr)
  aucs.append(roc_auc_score(y_test, y_pred))
  f1s.append(f1_score(y_test, y_pred, average="binary"))

  print(f"fold {fold} f1: {f1_score(y_test, y_pred, average='binary')}")

  tf.keras.backend.clear_session()
# Out:
# Found 1751 files belonging to 2 classes.
# FOLD 0
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  lambda (Lambda)             (None, 400, 400, 3)       0
#
#  vgg16 (Functional)          (None, 12, 12, 512)       14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 513
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 95s 542ms/step - loss: 0.5402 - binary_accuracy: 0.7336 - precision: 0.7343 - recall: 0.7236 - val_loss: 0.4532 - val_binary_accuracy: 0.7847 - val_precision: 0.8248 - val_recall: 0.7483
# Epoch 2/30
# 70/70 [==============================] - 11s 160ms/step - loss: 0.4512 - binary_accuracy: 0.7975 - precision: 0.8296 - recall: 0.7436 - val_loss: 0.4466 - val_binary_accuracy: 0.7917 - val_precision: 0.8583 - val_recall: 0.7219
# Epoch 3/30
# 70/70 [==============================] - 9s 130ms/step - loss: 0.4568 - binary_accuracy: 0.7984 - precision: 0.8247 - recall: 0.7527 - val_loss: 0.4486 - val_binary_accuracy: 0.7882 - val_precision: 0.8571 - val_recall: 0.7152
# Epoch 4/30
# 70/70 [==============================] - 9s 130ms/step - loss: 0.4397 - binary_accuracy: 0.8047 - precision: 0.8505 - recall: 0.7345 - val_loss: 0.4479 - val_binary_accuracy: 0.7882 - val_precision: 0.8571 - val_recall: 0.7152
# Epoch 5/30
# 70/70 [==============================] - 9s 131ms/step - loss: 0.4218 - binary_accuracy: 0.8182 - precision: 0.8537 - recall: 0.7636 - val_loss: 0.4469 - val_binary_accuracy: 0.7882 - val_precision: 0.8571 - val_recall: 0.7152
# Epoch 6/30
# 70/70 [==============================] - 9s 131ms/step - loss: 0.4190 - binary_accuracy: 0.8173 - precision: 0.8548 - recall: 0.7600 - val_loss: 0.4467 - val_binary_accuracy: 0.7882 - val_precision: 0.8571 - val_recall: 0.7152
# Epoch 7/30
# 70/70 [==============================] - 10s 146ms/step - loss: 0.4179 - binary_accuracy: 0.8119 - precision: 0.8501 - recall: 0.7527 - val_loss: 0.4449 - val_binary_accuracy: 0.7917 - val_precision: 0.8527 - val_recall: 0.7285
# Epoch 8/30
# 70/70 [==============================] - 9s 130ms/step - loss: 0.4146 - binary_accuracy: 0.8236 - precision: 0.8642 - recall: 0.7636 - val_loss: 0.4450 - val_binary_accuracy: 0.7951 - val_precision: 0.8538 - val_recall: 0.7351
# Epoch 9/30
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4324 - binary_accuracy: 0.8218 - precision: 0.8592 - recall: 0.7655 - val_loss: 0.4450 - val_binary_accuracy: 0.7951 - val_precision: 0.8538 - val_recall: 0.7351
# Epoch 10/30
# 70/70 [==============================] - 9s 129ms/step - loss: 0.4082 - binary_accuracy: 0.8290 - precision: 0.8571 - recall: 0.7855 - val_loss: 0.4452 - val_binary_accuracy: 0.7951 - val_precision: 0.8538 - val_recall: 0.7351
# Epoch 11/30
# 70/70 [==============================] - 9s 129ms/step - loss: 0.4417 - binary_accuracy: 0.8191 - precision: 0.8511 - recall: 0.7691 - val_loss: 0.4452 - val_binary_accuracy: 0.7951 - val_precision: 0.8538 - val_recall: 0.7351
# Epoch 12/30
# 70/70 [==============================] - ETA: 0s - loss: 0.4379 - binary_accuracy: 0.8173 - precision: 0.8519 - recall: 0.7636Restoring model weights from the end of the best epoch: 7.
# 70/70 [==============================] - 9s 130ms/step - loss: 0.4379 - binary_accuracy: 0.8173 - precision: 0.8519 - recall: 0.7636 - val_loss: 0.4452 - val_binary_accuracy: 0.7951 - val_precision: 0.8538 - val_recall: 0.7351
# Epoch 00012: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  lambda (Lambda)             (None, 400, 400, 3)       0
#
#  vgg16 (Functional)          (None, 12, 12, 512)       14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 513
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 15s 184ms/step - loss: 0.4367 - binary_accuracy: 0.8119 - precision_1: 0.8417 - recall_1: 0.7636 - val_loss: 0.4459 - val_binary_accuracy: 0.7882 - val_precision_1: 0.8571 - val_recall_1: 0.7152
# Epoch 2/30
# 70/70 [==============================] - 10s 146ms/step - loss: 0.4283 - binary_accuracy: 0.8182 - precision_1: 0.8508 - recall_1: 0.7673 - val_loss: 0.4455 - val_binary_accuracy: 0.7917 - val_precision_1: 0.
- val_binary_accuracy: 0.7917 - val_precision_1: 0.8527 - val_recall_1: 0.7285
# Epoch 23/30
# 70/70 [==============================] - 9s 131ms/step - loss: 0.4270 - binary_accuracy: 0.8146 - precision_1: 0.8583 - recall_1: 0.7491 - val_loss: 0.4453 - val_binary_accuracy: 0.7917 - val_precision_1: 0.8527 - val_recall_1: 0.7285
# Epoch 24/30
# 70/70 [==============================] - 9s 131ms/step - loss: 0.4359 - binary_accuracy: 0.8164 - precision_1: 0.8502 - recall_1: 0.7636 - val_loss: 0.4453 - val_binary_accuracy: 0.7917 - val_precision_1: 0.8527 - val_recall_1: 0.7285
# Epoch 25/30
# 70/70 [==============================] - ETA: 0s - loss: 0.4370 - binary_accuracy: 0.8011 - precision_1: 0.8337 - recall_1: 0.7473Restoring model weights from the end of the best epoch: 15.
# 70/70 [==============================] - 9s 132ms/step - loss: 0.4370 - binary_accuracy: 0.8011 - precision_1: 0.8337 - recall_1: 0.7473 - val_loss: 0.4452 - val_binary_accuracy: 0.7917 - val_precision_1: 0.8527 - val_recall_1: 0.7285
# Epoch 00025: early stopping
# fold 0 f1: 0.7815384615384616
# FOLD 1
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  lambda (Lambda)             (None, 400, 400, 3)       0
#
#  vgg16 (Functional)          (None, 12, 12, 512)       14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 513
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 63s 533ms/step - loss: 0.6030 - binary_accuracy: 0.7111 - precision: 0.7186 - recall: 0.7097 - val_loss: 0.4471 - val_binary_accuracy: 0.7847 - val_precision: 0.8839 - val_recall: 0.6689
# Epoch 2/30
# 70/70 [==============================] - 10s 149ms/step - loss: 0.4761 - binary_accuracy: 0.7912 - precision: 0.8208 - recall: 0.7540 - val_loss: 0.4268 - val_binary_accuracy: 0.7986 - val_precision: 0.9167 - val_recall: 0.6689
# Epoch 3/30
# 70/70 [==============================] - 9s 136ms/step - loss: 0.5041 - binary_accuracy: 0.7732 - precision: 0.8063 - recall: 0.7292 - val_loss: 0.4042 - val_binary_accuracy: 0.8333 - val_precision: 0.9310 - val_recall: 0.7297
# Epoch 4/30
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4671 - binary_accuracy: 0.7813 - precision: 0.8145 - recall: 0.7381 - val_loss: 0.3960 - val_binary_accuracy: 0.8438 - val_precision: 0.9120 - val_recall: 0.7703
# Epoch 5/30
# 70/70 [==============================] - 9s 136ms/step - loss: 0.4550 - binary_accuracy: 0.8011 - precision: 0.8359 - recall: 0.7575 - val_loss: 0.3922 - val_binary_accuracy: 0.8438 - val_precision: 0.9120 - val_recall: 0.7703
# Epoch 6/30
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4477 - binary_accuracy: 0.8074 - precision: 0.8475 - recall: 0.7575 - val_loss: 0.3904 - val_binary_accuracy: 0.8576 - val_precision: 0.9084 - val_recall: 0.8041
# Epoch 7/30
# 70/70 [==============================] - 9s 131ms/step - loss: 0.4508 - binary_accuracy: 0.8029 - precision: 0.8379 - recall: 0.7593 - val_loss: 0.3904 - val_binary_accuracy: 0.8576 - val_precision: 0.9084 - val_recall: 0.8041
# Epoch 8/30
# 70/70 [==============================] - 10s 148ms/step - loss: 0.4528 - binary_accuracy: 0.8029 - precision: 0.8392 - recall: 0.7575 - val_loss: 0.3903 - val_binary_accuracy: 0.8611 - val_precision: 0.9154 - val_recall: 0.8041
# Epoch 9/30
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4555 - binary_accuracy: 0.7903 - precision: 0.8192 - recall: 0.7540 - val_loss: 0.3902 - val_binary_accuracy: 0.8611 - val_precision: 0.9154 - val_recall: 0.8041
# Epoch 10/30
# 70/70 [==============================] - 10s 147ms/step - loss: 0.4590 - binary_accuracy: 0.7939 - precision: 0.8333 - recall: 0.7434 - val_loss: 0.3901 - val_binary_accuracy: 0.8611 - val_precision: 0.9154 - val_recall: 0.8041
# Epoch 11/30
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4565 - binary_accuracy: 0.7993 - precision: 0.8327 - recall: 0.7575 - val_loss: 0.3901 - val_binary_accuracy: 0.8611 - val_precision: 0.9154 - val_recall: 0.8041
# Epoch 12/30
# 70/70 [==============================] - 10s 148ms/step - loss: 0.4466 - binary_accuracy: 0.7984 - precision: 0.8298 - recall: 0.7593 - val_loss: 0.3900 - val_binary_accuracy: 0.8611 - val_precision: 0.9154 - val_recall: 0.8041
# Epoch 13/30
# 70/70 [==============================] - 10s 150ms/step - loss: 0.4540 - binary_accuracy: 0.7975 - precision: 0.8257 - recall: 0.7628 - val_loss: 0.3900 - val_binary_accuracy: 0.8611 - val_precision: 0.9154 - val_recall: 0.8041
# Epoch
- val_binary_accuracy: 0.8611 - val_precision_1: 0.9154 - val_recall_1: 0.8041
# Epoch 30/30
# 70/70 [==============================] - 9s 136ms/step - loss: 0.4525 - binary_accuracy: 0.8128 - precision_1: 0.8507 - recall_1: 0.7664 - val_loss: 0.3883 - val_binary_accuracy: 0.8611 - val_precision_1: 0.9154 - val_recall_1: 0.8041
# fold 1 f1: 0.7863777089783281
# FOLD 2
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  lambda (Lambda)             (None, 400, 400, 3)       0
#
#  vgg16 (Functional)          (None, 12, 12, 512)       14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 513
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 61s 515ms/step - loss: 0.5776 - binary_accuracy: 0.7165 - precision: 0.7211 - recall: 0.7068 - val_loss: 0.4641 - val_binary_accuracy: 0.7778 - val_precision: 0.8692 - val_recall: 0.6503
# Epoch 2/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.5153 - binary_accuracy: 0.7462 - precision: 0.7773 - recall: 0.6906 - val_loss: 0.4565 - val_binary_accuracy: 0.7951 - val_precision: 0.7800 - val_recall: 0.8182
# Epoch 3/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4782 - binary_accuracy: 0.7894 - precision: 0.8157 - recall: 0.7482 - val_loss: 0.4376 - val_binary_accuracy: 0.8125 - val_precision: 0.8248 - val_recall: 0.7902
# Epoch 4/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4796 - binary_accuracy: 0.7921 - precision: 0.8218 - recall: 0.7464 - val_loss: 0.4367 - val_binary_accuracy: 0.8056 - val_precision: 0.8085 - val_recall: 0.7972
# Epoch 5/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4535 - binary_accuracy: 0.8011 - precision: 0.8215 - recall: 0.7698 - val_loss: 0.4347 - val_binary_accuracy: 0.8090 - val_precision: 0.8188 - val_recall: 0.7902
# Epoch 6/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4522 - binary_accuracy: 0.7966 - precision: 0.8300 - recall: 0.7464 - val_loss: 0.4353 - val_binary_accuracy: 0.8090 - val_precision: 0.8188 - val_recall: 0.7902
# Epoch 7/30
# 70/70 [==============================] - 10s 149ms/step - loss: 0.4374 - binary_accuracy: 0.8065 - precision: 0.8223 - recall: 0.7824 - val_loss: 0.4343 - val_binary_accuracy: 0.8090 - val_precision: 0.8235 - val_recall: 0.7832
# Epoch 8/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4598 - binary_accuracy: 0.7984 - precision: 0.8307 - recall: 0.7500 - val_loss: 0.4344 - val_binary_accuracy: 0.8090 - val_precision: 0.8235 - val_recall: 0.7832
# Epoch 9/30
# 70/70 [==============================] - 10s 150ms/step - loss: 0.4563 - binary_accuracy: 0.7939 - precision: 0.8056 - recall: 0.7752 - val_loss: 0.4338 - val_binary_accuracy: 0.8160 - val_precision: 0.8358 - val_recall: 0.7832
# Epoch 10/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4535 - binary_accuracy: 0.8038 - precision: 0.8238 - recall: 0.7734 - val_loss: 0.4338 - val_binary_accuracy: 0.8160 - val_precision: 0.8358 - val_recall: 0.7832
# Epoch 11/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4495 - binary_accuracy: 0.7993 - precision: 0.8233 - recall: 0.7626 - val_loss: 0.4337 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 12/30
# 70/70 [==============================] - 10s 140ms/step - loss: 0.4538 - binary_accuracy: 0.7948 - precision: 0.8142 - recall: 0.7644 - val_loss: 0.4337 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 13/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4611 - binary_accuracy: 0.8038 - precision: 0.8250 - recall: 0.7716 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 14/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4614 - binary_accuracy: 0.8110 - precision: 0.8340 - recall: 0.7770 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 15/30
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4522 - binary_accuracy: 0.7975 - precision: 0.8264 - recall: 0.7536 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 16/30
# 70/70 [==============================] - 10s 140ms/step - loss: 0.4510 - binary_accuracy: 0.7957 - precision: 0.8182 - recall: 0.7608 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 17/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4479 - binary_accuracy: 0.8065 - precision: 0.8350 - recall: 0.7644 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 18/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4634 - binary_accuracy: 0.7948 - precision: 0.8280 - recall: 0.7446 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 19/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4498 - binary_accuracy: 0.8020 - precision: 0.8256 - recall: 0.7662 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 20/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4563 - binary_accuracy: 0.8083 - precision: 0.8242 - recall: 0.7842 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 21/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4434 - binary_accuracy: 0.8002 - precision: 0.8127 - recall: 0.7806 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 22/30
# 70/70 [==============================] - 10s 137ms/step - loss: 0.4557 - binary_accuracy: 0.8047 - precision: 0.8356 - recall: 0.7590 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 23/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4516 - binary_accuracy: 0.8020 - precision: 0.8387 - recall: 0.7482 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 24/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4492 - binary_accuracy: 0.7975 - precision: 0.8164 - recall: 0.7680 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 25/30
# 70/70 [==============================] - 9s 132ms/step - loss: 0.4447 - binary_accuracy: 0.8020 - precision: 0.8206 - recall: 0.7734 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 26/30
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4454 - binary_accuracy: 0.8137 - precision: 0.8428 - recall: 0.7716 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 27/30
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4413 - binary_accuracy: 0.8065 - precision: 0.8311 - recall: 0.7698 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 28/30
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4526 - binary_accuracy: 0.8020 - precision: 0.8218 - recall: 0.7716 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 29/30
# 70/70 [==============================] - ETA: 0s - loss: 0.4601 - binary_accuracy: 0.7975 - precision: 0.8290 - recall: 0.7500Restoring model weights from the end of the best epoch: 24.
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4601 - binary_accuracy: 0.7975 - precision: 0.8290 - recall: 0.7500 - val_loss: 0.4336 - val_binary_accuracy: 0.8194 - val_precision: 0.8421 - val_recall: 0.7832
# Epoch 00029: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  lambda (Lambda)             (None, 400, 400, 3)       0
#
#  vgg16 (Functional)          (None, 12, 12, 512)       14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 513
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 12s 145ms/step - loss: 0.4514 - binary_accuracy: 0.8029 - precision_1: 0.8297 - recall_1: 0.7626 - val_loss: 0.4329 - val_binary_accuracy: 0.8125 - val_precision_1: 0.8450 - val_recall_1: 0.7622
# Epoch 2/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4612 - binary_accuracy: 0.7939 - precision_1: 0.8225 - recall_1: 0.7500 - val_loss: 0.4330 - val_binary_accuracy: 0.8125 - val_precision_1: 0.8450 - val_recall_1: 0.7622
# Epoch 3/30
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4422 - binary_accuracy: 0.8011 - precision_1: 0.8304 - recall_1: 0.7572 - val_loss: 0.4332 - val_binary_accuracy: 0.8125 - val_precision_1: 0.8397 - val_recall_1: 0.7692
# Epoch 4/30
# 70/70 [==============================] - 10s 149ms/step - loss: 0.4505 - binary_accuracy: 0.7867 - precision_1: 0.8121 - recall_1: 0.7464 - val_loss: 0.4329 - val_binary_accuracy: 0.8125 - val_precision_1: 0.8450 - val_recall_1: 0.7622
# Epoch 5/30
# 70/70 [==============================] - 11s 152ms/step - loss: 0.4544 - binary_accuracy: 0.8029 - precision_1: 0.8377 - recall_1: 0.7518 - val_loss: 0.4328 - val_binary_accuracy: 0.8090 - val_precision_1: 0.8385 - val_recall_1: 0.7622
# Epoch 6/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4443 - binary_accuracy: 0.8065 - precision_1: 0.8337 - recall_1: 0.7662 - val_loss: 0.4329 - val_binary_accuracy: 0.8125 - val_precision_1: 0.8397 - val_recall_1: 0.7692
# Epoch 7/30
# 70/70 [==============================] - 10s 149ms/step - loss: 0.4533 - binary_accuracy: 0.7975 - precision_1: 0.8226 - recall_1: 0.7590 - val_loss: 0.4327 - val_binary_accuracy: 0.8125 - val_precision_1: 0.8397 - val_recall_1: 0.7692
# Epoch 8/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4459 - binary_accuracy: 0.8020 - precision_1: 0.8218 - recall_1: 0.7716 - val_loss: 0.4323 - val_binary_accuracy: 0.8090 - val_precision_1: 0.8385 - val_recall_1: 0.7622
# Epoch
- val_binary_accuracy: 0.8090 - val_precision_1: 0.8385 - val_recall_1: 0.7622
# Epoch 27/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4385 - binary_accuracy: 0.8047 - precision_1: 0.8279 - recall_1: 0.7698 - val_loss: 0.4315 - val_binary_accuracy: 0.8090 - val_precision_1: 0.8385 - val_recall_1: 0.7622
# Epoch 28/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4610 - binary_accuracy: 0.7957 - precision_1: 0.8232 - recall_1: 0.7536 - val_loss: 0.4316 - val_binary_accuracy: 0.8090 - val_precision_1: 0.8385 - val_recall_1: 0.7622
# Epoch 29/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4513 - binary_accuracy: 0.8011 - precision_1: 0.8252 - recall_1: 0.7644 - val_loss: 0.4315 - val_binary_accuracy: 0.8090 - val_precision_1: 0.8385 - val_recall_1: 0.7622
# Epoch 30/30
# 70/70 [==============================] - 10s 150ms/step - loss: 0.4438 - binary_accuracy: 0.8137 - precision_1: 0.8324 - recall_1: 0.7860 - val_loss: 0.4315 - val_binary_accuracy: 0.8090 - val_precision_1: 0.8385 - val_recall_1: 0.7622
# fold 2 f1: 0.8067226890756302
# FOLD 3
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  lambda (Lambda)             (None, 400, 400, 3)       0
#
#  vgg16 (Functional)          (None, 12, 12, 512)       14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# ...
#  lambda (Lambda)             (None, 400, 400, 3)       0
#
#  vgg16 (Functional)          (None, 12, 12, 512)       14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 513
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 58s 485ms/step - loss: 0.5301 - binary_accuracy: 0.7366 - precision: 0.7299 - recall: 0.7121 - val_loss: 0.5093 - val_binary_accuracy: 0.7396 - val_precision: 0.8148 - val_recall: 0.6154
# Epoch 2/30
# 70/70 [==============================] - 11s 152ms/step - loss: 0.4676 - binary_accuracy: 0.7875 - precision: 0.7952 - recall: 0.7477 - val_loss: 0.4678 - val_binary_accuracy: 0.7778 - val_precision: 0.8435 - val_recall: 0.6783
# Epoch 3/30
# 70/70 [==============================] - 11s 151ms/step - loss: 0.4525 - binary_accuracy: 0.8036 - precision: 0.8182 - recall: 0.7570 - val_loss: 0.4588 - val_binary_accuracy: 0.7847 - val_precision: 0.8000 - val_recall: 0.7552
# Epoch 4/30
# 70/70 [==============================] - 11s 151ms/step - loss: 0.4358 - binary_accuracy: 0.8036 - precision: 0.8195 - recall: 0.7551 - val_loss: 0.4544 - val_binary_accuracy: 0.7708 - val_precision: 0.7984 - val_recall: 0.7203
# Epoch 5/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4450 - binary_accuracy: 0.7920 - precision: 0.8020 - recall: 0.7495 - val_loss: 0.4511 - val_binary_accuracy: 0.7674 - val_precision: 0.7969 - val_recall: 0.7133
# Epoch 6/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4382 - binary_accuracy: 0.8143 - precision: 0.8290 - recall: 0.7701 - val_loss: 0.4507 - val_binary_accuracy: 0.7639 - val_precision: 0.8000 - val_recall: 0.6993
# Epoch 7/30
# 70/70 [==============================] - 10s 139ms/step - loss: 0.4390 - binary_accuracy: 0.8018 - precision: 0.8174 - recall: 0.7533 - val_loss: 0.4504 - val_binary_accuracy: 0.7708 - val_precision: 0.8031 - val_recall: 0.7133
# Epoch 8/30
# 70/70 [==============================] - 10s 140ms/step - loss: 0.4315 - binary_accuracy: 0.8125 - precision: 0.8296 - recall: 0.7645 - val_loss: 0.4502 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 9/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4279 - binary_accuracy: 0.8107 - precision: 0.8236 - recall: 0.7682 - val_loss: 0.4501 - val_binary_accuracy: 0.7743 - val_precision: 0.8047 - val_recall: 0.7203
# Epoch 10/30
# 70/70 [==============================] - 10s 151ms/step - loss: 0.4451 - binary_accuracy: 0.8107 - precision: 0.8249 - recall: 0.7664 - val_loss: 0.4501 - val_binary_accuracy: 0.7743 - val_precision: 0.8047 - val_recall: 0.7203
# Epoch 11/30
# 70/70 [==============================] - 11s 158ms/step - loss: 0.4353 - binary_accuracy: 0.7973 - precision: 0.8263 - recall: 0.7290 - val_loss: 0.4501 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 12/30
# 70/70 [==============================] - 10s 149ms/step - loss: 0.4284 - binary_accuracy: 0.8143 - precision: 0.8162 - recall: 0.7888 - val_loss: 0.4501 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 13/30
# 70/70 [==============================] - 10s 149ms/step - loss: 0.4270 - binary_accuracy: 0.8205 - precision: 0.8367 - recall: 0.7757 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 14/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4552 - binary_accuracy: 0.7937 - precision: 0.8115 - recall: 0.7402 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 15/30
# 70/70 [==============================] - 10s 148ms/step - loss: 0.4409 - binary_accuracy: 0.8152 - precision: 0.8254 - recall: 0.7776 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 16/30
# 70/70 [==============================] - 11s 161ms/step - loss: 0.4393 - binary_accuracy: 0.8027 - precision: 0.8191 - recall: 0.7533 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 17/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4491 - binary_accuracy: 0.7955 - precision: 0.8000 - recall: 0.7626 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 18/30
# 70/70 [==============================] - 11s 152ms/step - loss: 0.4216 - binary_accuracy: 0.8036 - precision: 0.8221 - recall: 0.7514 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 19/30
# 70/70 [==============================] - 10s 151ms/step - loss: 0.4393 - binary_accuracy: 0.8027 - precision: 0.8230 - recall: 0.7477 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 20/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4300 - binary_accuracy: 0.8107 - precision: 0.8316 - recall: 0.7570 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 21/30
# 70/70 [==============================] - 10s 149ms/step - loss: 0.4432 - binary_accuracy: 0.7964 - precision: 0.8040 - recall: 0.7589 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 22/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4349 - binary_accuracy: 0.7991 - precision: 0.8125 - recall: 0.7533 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 23/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4414 - binary_accuracy: 0.8062 - precision: 0.8118 - recall: 0.7738 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 24/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4368 - binary_accuracy: 0.8098 - precision: 0.8313 - recall: 0.7551 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 25/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4306 - binary_accuracy: 0.8134 - precision: 0.8327 - recall: 0.7626 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 26/30
# 70/70 [==============================] - ETA: 0s - loss: 0.4411 - binary_accuracy: 0.7991 - precision: 0.8138 - recall: 0.7514Restoring model weights from the end of the best epoch: 21.
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4411 - binary_accuracy: 0.7991 - precision: 0.8138 - recall: 0.7514 - val_loss: 0.4500 - val_binary_accuracy: 0.7778 - val_precision: 0.8062 - val_recall: 0.7273
# Epoch 00026: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 400, 400, 3)]     0
#
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  lambda (Lambda)             (None, 400, 400, 3)       0
#
#  vgg16 (Functional)          (None, 12, 12, 512)       14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 513
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/30
# 70/70 [==============================] - 12s 146ms/step - loss: 0.4356 - binary_accuracy: 0.8054 - precision_1: 0.8282 - recall_1: 0.7477 - val_loss: 0.4506 - val_binary_accuracy: 0.7778 - val_precision_1: 0.7970 - val_recall_1: 0.7413
# Epoch 2/30
# 70/70 [==============================] - 11s 163ms/step - loss: 0.4436 - binary_accuracy: 0.8045 - precision_1: 0.8098 - recall_1: 0.7720 - val_loss: 0.4495 - val_binary_accuracy: 0.7812 - val_precision_1: 0.8077 - val_recall_1: 0.7343
# Epoch 3/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4505 - binary_accuracy: 0.8080 - precision_1: 0.8333 - recall_1: 0.7477 - val_loss: 0.4495 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 4/30
# 70/70 [==============================] - 10s 150ms/step - loss: 0.4238 - binary_accuracy: 0.8071 - precision_1: 0.8222 - recall_1: 0.7607 - val_loss: 0.4493 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 5/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4486 - binary_accuracy: 0.8018 - precision_1: 0.8099 - recall_1: 0.7645 - val_loss: 0.4493 - val_binary_accuracy: 0.7812 - val_precision_1: 0.8077 - val_recall_1: 0.7343
# Epoch 6/30
# 70/70 [==============================] - 10s 148ms/step - loss: 0.4375 - binary_accuracy: 0.8018 - precision_1: 0.8136 - recall_1: 0.7589 - val_loss: 0.4490 - val_binary_accuracy: 0.7743 - val_precision_1: 0.8047 - val_recall_1: 0.7203
# Epoch 7/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4354 - binary_accuracy: 0.8116 - precision_1: 0.8389 - recall_1: 0.7495 - val_loss: 0.4494 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 8/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4329 - binary_accuracy: 0.8161 - precision_1: 0.8283 - recall_1: 0.7757 - val_loss: 0.4492 - val_binary_accuracy: 0.7812 - val_precision_1: 0.8030 - val_recall_1: 0.7413
# Epoch 9/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4453 - binary_accuracy: 0.8000 - precision_1: 0.8116 - recall_1: 0.7570 - val_loss: 0.4491 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 10/30
# 70/70 [==============================] - 10s 150ms/step - loss: 0.4251 - binary_accuracy: 0.8170 - precision_1: 0.8287 - recall_1: 0.7776 - val_loss: 0.4489 - val_binary_accuracy: 0.7812 - val_precision_1: 0.8077 - val_recall_1: 0.7343
# Epoch 11/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4447 - binary_accuracy: 0.7991 - precision_1: 0.8112 - recall_1: 0.7551 - val_loss: 0.4490 - val_binary_accuracy: 0.7812 - val_precision_1: 0.8077 - val_recall_1: 0.7343
# Epoch 12/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4329 - binary_accuracy: 0.8054 - precision_1: 0.8255 - recall_1: 0.7514 - val_loss: 0.4490 - val_binary_accuracy: 0.7812 - val_precision_1: 0.8077 - val_recall_1: 0.7343
# Epoch 13/30
# 70/70 [==============================] - 10s 150ms/step - loss: 0.4268 - binary_accuracy: 0.8205 - precision_1: 0.8381 - recall_1: 0.7738 - val_loss: 0.4488 - val_binary_accuracy: 0.7778 - val_precision_1: 0.8062 - val_recall_1: 0.7273
# Epoch 14/30
# 70/70 [==============================] - 10s 140ms/step - loss: 0.4344 - binary_accuracy: 0.8107 - precision_1: 0.8330 - recall_1: 0.7551 - val_loss: 0.4487 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 15/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4411 - binary_accuracy: 0.8080 - precision_1: 0.8150 - recall_1: 0.7738 - val_loss: 0.4486 - val_binary_accuracy: 0.7812 - val_precision_1: 0.8077 - val_recall_1: 0.7343
# Epoch 16/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4197 - binary_accuracy: 0.8134 - precision_1: 0.8247 - recall_1: 0.7738 - val_loss: 0.4484 - val_binary_accuracy: 0.7743 - val_precision_1: 0.8047 - val_recall_1: 0.7203
# Epoch 17/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4204 - binary_accuracy: 0.8143 - precision_1: 0.8303 - recall_1: 0.7682 - val_loss: 0.4483 - val_binary_accuracy: 0.7743 - val_precision_1: 0.8047 - val_recall_1: 0.7203
# Epoch 18/30
# 70/70 [==============================] - 10s 138ms/step - loss: 0.4304 - binary_accuracy: 0.8000 - precision_1: 0.8104 - recall_1: 0.7589 - val_loss: 0.4483 - val_binary_accuracy: 0.7778 - val_precision_1: 0.8062 - val_recall_1: 0.7273
# Epoch 19/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4345 - binary_accuracy: 0.8107 - precision_1: 0.8289 - recall_1: 0.7607 - val_loss: 0.4484 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 20/30
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4464 - binary_accuracy: 0.8009 - precision_1: 0.8184 - recall_1: 0.7495 - val_loss: 0.4485 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 21/30
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4438 - binary_accuracy: 0.8027 - precision_1: 0.8165 - recall_1: 0.7570 - val_loss: 0.4484 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 22/30
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4291 - binary_accuracy: 0.8116 - precision_1: 0.8164 - recall_1: 0.7813 - val_loss: 0.4484 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 23/30
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4346 - binary_accuracy: 0.8018 - precision_1: 0.8267 - recall_1: 0.7402 - val_loss: 0.4485 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 24/30
# 70/70 [==============================] - 9s 133ms/step - loss: 0.4406 - binary_accuracy: 0.8054 - precision_1: 0.8268 - recall_1: 0.7495 - val_loss: 0.4485 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 25/30
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4220 - binary_accuracy: 0.8214 - precision_1: 0.8304 - recall_1: 0.7869 - val_loss: 0.4484 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 26/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4305 - binary_accuracy: 0.8089 - precision_1: 0.8216 - recall_1: 0.7664 - val_loss: 0.4483 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 27/30
# 70/70 [==============================] - 9s 134ms/step - loss: 0.4254 - binary_accuracy: 0.8134 - precision_1: 0.8300 - recall_1: 0.7664 - val_loss: 0.4484 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 28/30
# 70/70 [==============================] - ETA: 0s - loss: 0.4333 - binary_accuracy: 0.8054 - precision_1: 0.8309 - recall_1: 0.7439Restoring model weights from the end of the best epoch: 18.
# 70/70 [==============================] - 9s 135ms/step - loss: 0.4333 - binary_accuracy: 0.8054 - precision_1: 0.8309 - recall_1: 0.7439 - val_loss: 0.4485 - val_binary_accuracy: 0.7847 - val_precision_1: 0.8092 - val_recall_1: 0.7413
# Epoch 00028: early stopping
# fold 4 f1: 0.7702265372168285

# %% [markdown]
# ## Plot ROC (after training run)

# %%
f1s
# Out:
# [0.7815384615384616,
#  0.7863777089783281,
#  0.8067226890756302,
#  0.8083832335329342,
#  0.7702265372168285]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="ROC Curve (" +notebook_iteration + ")",
)
ax.legend(loc="lower right")
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[0, 0.2],
    ylim=[0.8, 1],
    title= "ROC Curve (" +notebook_iteration + ")" + " (zoomed in at top left)",
)
ax.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Plot ROC (from saved models)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)


y_preds = []
y_tests = []
tprs = []
aucs = []
f1s = []
mean_fpr = np.linspace(0, 1, 100)

for fold in range(num_splits):
  test_ds = full_ds.shard(num_splits, index=fold)
  x_test, y_test = [], []
  for images, labels in test_ds.unbatch():
    x_test.append(images.numpy())
    y_test.append(labels.numpy())
  x_test = np.array(x_test)
  y_test = np.array(y_test)

  load_path = Path( model_dir / str(fold) / "final_network.h5" )
  model = keras.models.load_model( load_path)
  print(f"Loading {Path(load_path)}")

  # test predictions and calculate test metrics
  y_pred = model.predict(x_test).ravel().round().astype(int)
  y_preds.append(y_pred)
  y_tests.append(y_test)

  fpr, tpr, thresholds = roc_curve(y_test, y_pred)
  interp_tpr = np.interp(mean_fpr, fpr, tpr)
  interp_tpr[0] = 0.0
  tprs.append(interp_tpr)
  aucs.append(roc_auc_score(y_test, y_pred))
  f1s.append(f1_score(y_test, y_pred, average="binary"))

  print(f"fold {fold} f1: {f1_score(y_test, y_pred, average='binary')}")
  print(f1s)

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[-0.05, 1.05],
    ylim=[-0.05, 1.05],
    title="ROC Curve (" +notebook_iteration + ")",
)
ax.legend(loc="lower right")
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
for i in range(num_splits):
  viz = RocCurveDisplay.from_predictions(
        y_tests[i],
        y_preds[i],
        name="ROC fold {}, (F1 = {:.2f})".format(i, float(f1s[i])),
        alpha=0.3,
        lw=1,
        ax=ax)

ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(
    mean_fpr,
    mean_tpr,
    color="b",
    label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
    lw=2,
    alpha=0.8,
)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(
    mean_fpr,
    tprs_lower,
    tprs_upper,
    color="grey",
    alpha=0.2,
    label=r"$\pm$ 1 std. dev.",
)

ax.set(
    xlim=[0, 0.2],
    ylim=[0.8, 1],
    title= "ROC Curve (" +notebook_iteration + ")" + " (zoomed in at top left)",
)
ax.legend(loc="lower right")
plt.show()
# Out:
# Found 1751 files belonging to 2 classes.
# Loading /content/drive/MyDrive/OTH/space-eye/models/i13/0/final_network.h5
# fold 0 f1: 0.7607361963190183
# [0.7607361963190183]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i13/1/final_network.h5
# fold 1 f1: 0.8404907975460123
# [0.7607361963190183, 0.8404907975460123]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i13/2/final_network.h5
# fold 2 f1: 0.7987421383647799
# [0.7607361963190183, 0.8404907975460123, 0.7987421383647799]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i13/3/final_network.h5
# fold 3 f1: 0.8169934640522876
# [0.7607361963190183, 0.8404907975460123, 0.7987421383647799, 0.8169934640522876]
# Loading /content/drive/MyDrive/OTH/space-eye/models/i13/4/final_network.h5
# fold 4 f1: 0.7888198757763976
# [0.7607361963190183, 0.8404907975460123, 0.7987421383647799, 0.8169934640522876, 0.7888198757763976]

# %% [markdown]
# ## Tune

# %% [markdown]
# informative only, not set up to change model parameters automatically

# %%
# !pip install -q keras-tuner
# Out:
#      |████████████████████████████████| 98 kB 3.2 MB/s

# %%
import keras_tuner as kt
import numpy as np

tf.keras.backend.clear_session()  # clear the previous runs
batch_size = 128
epochs = 5

#set up dataset
full_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed=1337,
    image_size=(img_width, img_height),
    batch_size=batch_size,
)

val_ds = full_ds.shard(10, index=0)

train_ds = full_ds.take(0)
for i in range(1, 10):
  train_ds = full_ds.concatenate(full_ds.shard(10, index=i))

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(tuner_dir / 'tuned_network.h5', save_best_only=True, monitor='recall', mode='max')
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)

tuner = kt.BayesianOptimization(hypermodel=build_model_tuner, objective='recall', max_trials=5)
print(tuner.search_space_summary(extended=True))

tuner.search(train_ds, epochs=epochs, validation_data=val_ds, callbacks=[checkpoint_cb, early_stopping_cb], verbose=2)

print(tuner.results_summary())
# Out:
# Found 1751 files belonging to 2 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-31eee7e3da03> in <module>()
#      23 early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
#      24
# ---> 25 tuner = kt.BayesianOptimization(hypermodel=build_model_tuner, objective='recall', max_trials=5)
#      26 print(tuner.search_space_summary(extended=True))
#      27
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/tuners/bayesian.py in __init__(self, hypermodel, objective, max_trials, num_initial_points, alpha, beta, seed, hyperparameters, tune_new_entries, allow_new_entries, **kwargs)
#     409             hyperparameters=hyperparameters,
#     410             tune_new_entries=tune_new_entries,
# --> 411             allow_new_entries=allow_new_entries,
#     412         )
#     413         super(
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/tuners/bayesian.py in __init__(self, objective, max_trials, num_initial_points, alpha, beta, seed, hyperparameters, allow_new_entries, tune_new_entries)
#     173             tune_new_entries=tune_new_entries,
#     174             allow_new_entries=allow_new_entries,
# --> 175             seed=seed,
#     176         )
#     177         self.num_initial_points = num_initial_points
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/oracle.py in __init__(self, objective, max_trials, hyperparameters, allow_new_entries, tune_new_entries, seed)
#      68         seed=None,
#      69     ):
# ---> 70         self.objective = _format_objective(objective)
#      71         self.max_trials = max_trials
#      72         if not hyperparameters:
#
# /usr/local/lib/python3.7/dist-packages/keras_tuner/engine/oracle.py in _format_objective(objective)
#     464             )
#     465             error_msg = error_msg.format(obj=objective)
# --> 466             raise ValueError(error_msg)
#     467         return Objective(name=objective, direction=direction)
#     468     else:
#
# ValueError: Could not infer optimization direction ("min" or "max") for unknown metric "recall". Please specify the objective  asa `keras_tuner.Objective`, for example `keras_tuner.Objective("recall", direction="min")`.
